# %%
from google.colab import auth
from datetime import datetime
auth.authenticate_user()
# !gsutil -m cp -r gs://predict_cfs/distance3/gage_data .
# Out:
# Copying gs://predict_cfs/distance3/gage_data/10011500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10015700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10016900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10015900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10020100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10023000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10020300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10028500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10026500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10032000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10038000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10041000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10104700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10105900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10108400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10109000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10111700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10113500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10118000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10126000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10128000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10128500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10129300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10129500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10129900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10130500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10130000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10131000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10132000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10132500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10133540stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10133600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10133601stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10133602stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10133650stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10133895stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10133800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10133980stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10134500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10136600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10136500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10137500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10137000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10137900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10139300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10140100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10140700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10141000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10142000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10143500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10145400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10146000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10146400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10147100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10148200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10148510stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10149000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10149400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10149500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10150500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10153100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10153800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10154200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10154500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10155000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10155100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10155200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10155300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10155400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10155500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10156000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10157000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10157500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10159500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10163000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10164500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10166430stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10167000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10167230stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10167450stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10167499stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10167700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10167800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10168000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10168150stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10168200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10168499stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10169000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10168800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10169999stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10170250stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10170500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10171000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10171305stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10171600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172220stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172351stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172352stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172499stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172630stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172650stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172640stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172726stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172727stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172750stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172791stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172795stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172765stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172805stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172870stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172875stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10172952stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10173450stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10174500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10180000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10183500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10183900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10189000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10191500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10194000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10194200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10205030stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10205000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10206000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10208500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10215700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10215900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10217000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10219000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10219200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10224000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10224100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10234500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10237000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10239000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10241470stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10241600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10242000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10242300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10366000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10371500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10378500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10384000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10388000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10390000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10393500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10396000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/10406500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1111300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1109403stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1111410stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1111500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1112268stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1112382stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1112500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1113695stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1113760stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1113895stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1114000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1114500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1115098stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1115110stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1115114stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1115120stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1115170stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1115183stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1115184stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1115187stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1115190stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1115265stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1115275stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1115276stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1115280stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1115297stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1115500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1115630stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1115670stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1115770stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1116000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1116500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1116905stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1117000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1117350stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11173545stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1117370stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1117424stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1117430stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1117410stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1117468stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1117420stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1117471stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1117500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1117600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1117800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1118000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1118010stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1118500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1118360stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1133000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1134500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1135150stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1135300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1135500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1138500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1139000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1139800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1140817stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1142500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1144000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11486990stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11491400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11492400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11493500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11495800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11497500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11499100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11501000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11502500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11504115stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11504290stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11507500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1150900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11509105stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11509200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11509250stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11509500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11509340stations.json...
# Copying gs://predict_cfs/distance3/gage_data/11510700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1151500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1153000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1153550stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1154000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1155500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1200000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12010000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12013500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12017000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12019310stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12020000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12020525stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12020800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12021800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12024000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12024400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12025000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12025100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12025700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12025310stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12026150stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12026400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12027500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12028060stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12031000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12035000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12035002stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12035100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12035450stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12035400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12036000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12036400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12037400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12039005stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12039500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12039510stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1203951610stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12040500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12040700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12040900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12041200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12042800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12043000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12043015stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12043163stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12043300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12044910stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12044900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12045500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12046260stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12048000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12048650stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12049000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12052200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12052210stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12054000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12056500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12058790stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12058800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12059500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12060500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12061250stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12061500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12069600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12069651stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12070000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12070040stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12070045stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12070050stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12073500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12078705stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12076800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12078720stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12078730stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12079000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12080010stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12080500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12081000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12080670stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12081010stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12083000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12086000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12082500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12086500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12087000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12088000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12089208stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12089500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12090340stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12090360stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12090365stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12090380stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12090400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12090452stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12090480stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12090500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12091100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12091180stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12091200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12091300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12091290stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12093500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12092000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12091500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12094000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12095000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12096505stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12096500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12096865stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12097500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12097820stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12097850stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12098500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12098920stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12099100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12099000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12099200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12099600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12100000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12100490stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12100494stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12100496stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12100498stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12100500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12101100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12101102stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12101470stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12101500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12102025stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12102075stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12102140stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12102190stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12102212stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12102900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12102920stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12103000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12103020stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12103205stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12103212stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12103207stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12103210stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12103220stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12103330stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12103380stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12104500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12105900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12106700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12108500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12112600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12113000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12113344stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12113346stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12113347stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12113349stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12113350stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12113390stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12113415stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12114500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12115000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12115500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12115700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12115800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12116100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12116400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12116500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12117000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12117500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12117600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12117700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12117800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12117820stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12118400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12118500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12119000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12120000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12120500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12120600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12121600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12121720stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12121815stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12121830stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12122500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12125200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12127100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12128000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12131500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12134500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12137290stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12135000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12137800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12141300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12138160stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12142000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12143400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12143600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12143700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12143900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12144000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12144500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12145500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12147470stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12147500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12147600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12148000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12148300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12148500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12149000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12150400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12150800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12155300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12155500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12157025stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12157250stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12158010stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12158040stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12158032stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12161000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12166150stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12166185stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12166240stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12166400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12166300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12166495stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12167000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12168500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12170300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12170305stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12170310stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12170320stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12170315stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12170400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12170440stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12172000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12173500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12175500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12178000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12178100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12179000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12179900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12181090stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12181000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12181100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12181200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12182500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12184700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12185300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12186000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12186450stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12187500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12187900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12187985stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12188380stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12189500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12190400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12190710stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12190718stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12192700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12193400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12193500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12194000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12199000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12199600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12200500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12200684stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12200690stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12200701stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12200728stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12200730stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12200733stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12200737stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12200750stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12200762stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12201500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12201950stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12201960stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12202300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12202400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12202310stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12202450stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12205000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12205245stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12206900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12207750stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12207850stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12208000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12209000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12209490stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12210000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12210220stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12210500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12210700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12210900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12211195stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12211200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12212050stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12212100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12212200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12212430stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12213100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12213140stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12213145stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12214350stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12214500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12396500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12396900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12397100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12398000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12399500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12400900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12401500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12404500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12404900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12409000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12420500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12419500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12422000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12422500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12422990stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12424000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12426000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12427000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12431000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12431500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12433200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12433542stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12433556stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12433890stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12433561stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12434110stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12438900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12434590stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12438905stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12439300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12439500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12442500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12444290stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12444550stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12445000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12445500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12445900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12446150stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12446400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12446995stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12447200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12447285stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12447370stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12447382stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12447383stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12447387stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12447390stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12447600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12448000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12448500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12448620stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12448990stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12448992stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12448996stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12448998stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12449710stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12449500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12449760stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12449950stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12452500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12452800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12451000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12452890stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12452990stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12457000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12456500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12458000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12459000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12462500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12464606stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12464770stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12464800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12465000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12465400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12467000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12470500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12471400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12472380stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12472600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12472800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12473503stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12473508stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12473740stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12479500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12484500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12488500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12499000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12500420stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12500450stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12502500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12505450stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12506000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12508850stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12508990stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12509050stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12509698stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12510500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12510625stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12510618stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12510650stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12510655stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12512550stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12513000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12513650stations.json...
# Copying gs://predict_cfs/distance3/gage_data/12514095stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13010065stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13011000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13011500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13011820stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13011900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13012465stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13012490stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13012475stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13013650stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13014300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13014500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13015000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13016240stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13016305stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13016310stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13016315stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13016450stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13018000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13018250stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13018350stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13018300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13018750stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13019438stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1302020stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13022500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13022920stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13022925stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13023000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13025500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13027500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1303000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1303500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1304000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1304500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13046680stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1305000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1305500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1306460stations.json...
# Copying gs://predict_cfs/distance3/gage_data/13077700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1308000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1308500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1309500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1309950stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1309990stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1310000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/1310500stations.json...
# ...
# Copying gs://predict_cfs/distance3/gage_data/8470500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/8475000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/8473700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/8477110stations.json...
# Copying gs://predict_cfs/distance3/gage_data/8480595stations.json...
# Copying gs://predict_cfs/distance3/gage_data/8481500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9180000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9180500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9182200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9182400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9183000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9183500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9183600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9184000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9185100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9185600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9186500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9187550stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9188500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9196500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9196940stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9196960stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9197000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9203000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9205000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9208400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9209400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9210500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9211200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9213500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9215000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9215550stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9216050stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9217000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9217900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9218500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9219200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9220000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9223000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9222400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9223385stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9224700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9229500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9230300stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9234500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9235100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9235600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9256000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9257000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9258050stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9258980stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9259000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9261000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9266500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9261700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9265500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9267500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9268900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9268500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9270500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9271425stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9271400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9271450stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9271550stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9272400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9274900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9275500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9276600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9277800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9277500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9278000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9278500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9279000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9279100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9279150stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9285900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9285000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9286100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9286700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9288000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9288180stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9288400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9289500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9291000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9292000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9292500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9295000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9295100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9296800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9299400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9299500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9301500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9302000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9306500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9306800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9308500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9309600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9310000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9310500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9310700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9312600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9312700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9312800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9313000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9314280stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9314500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9315000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9319000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9326500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9323000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9327000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9328060stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9328500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9328910stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9328920stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9328990stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9329050stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9330000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9330230stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9330410stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9332100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9330500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9332600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9332800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9333500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9337000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9335200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9337500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9338900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9339000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9346050stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9355500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9364010stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9357255stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9357245stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9364500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9365000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9367000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9367500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9367536stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9367540stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9367580stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9367950stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9368000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9372400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9376800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9378170stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9378200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9378600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9378630stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9378650stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9379500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9378700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9381500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9381800stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9386900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9386910stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9386915stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9386917stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9386919stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9386925stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9386950stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9395350stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9395630stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9403600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9403690stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9404450stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9404700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9404900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9405490stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9405499stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9405500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9405501stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9405900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9406000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9406100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9406150stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9406640stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9406700stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9406900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9407000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9407810stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9408000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9408135stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9408150stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9408175stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9408195stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9408400stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9408500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9409100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9410100stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9409880stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9413000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9413200stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9413500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9413900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9429980stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9430010stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9430030stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9430020stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9430500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9430600stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9430815stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9430820stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9430825stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9431500stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9431503stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442625stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9432000stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442661stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442662stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442666stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442669stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442667stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442677stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442680stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442681stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442682stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442683stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442684stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442704stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442692stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442755stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442760stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442956stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442960stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9443900stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9442958stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9443938stations.json...
# Copying gs://predict_cfs/distance3/gage_data/9444000stations.json...
# | [6.1k/6.1k files][  3.5 GiB/  3.5 GiB] 100% Done  28.3 MiB/s ETA 00:00:00
# Operation completed over 6.1k objects/3.5 GiB.

# %%
from math import radians, cos, sin, asin, sqrt
import pandas as pd
import os
import json
from typing import Set, Tuple, Dict
import requests
from datetime import datetime, timedelta

def get_closest_gage(gage_df:pd.DataFrame, station_df:pd.DataFrame, path_dir:str, start_row:int, end_row:int):
  # Function that calculates the closest weather stations to gage and stores in JSON
  # Base u
  for row in range(start_row, end_row):
    gage_info = {}
    gage_info["river_id"] = int(gage_df.iloc[row]['id'])
    gage_lat = gage_df.iloc[row]['latitude']
    gage_long = gage_df.iloc[row]['logitude']
    gage_info["stations"] = []
    total = len(station_df.index)
    for i in range(0, total):
      stat_row = station_df.iloc[i]
      dist = haversine(stat_row["lon"], stat_row["lat"], gage_long, gage_lat)
      st_id = stat_row['stid']
      gage_info["stations"].append({"station_id":st_id, "dist":dist})
    gage_info["stations"] = sorted(gage_info['stations'], key = lambda i: i["dist"], reverse=True) 
    with open(os.path.join(path_dir, str(gage_info["river_id"]) + "stations.json"), 'w') as w:
      json.dump(gage_info, w)
      if count%100 == 0:
        print("Currently at " + str(count))
      count +=1 

def haversine(lon1, lat1, lon2, lat2):
  """
  Calculate the great circle distance between two points 
  on the earth (specified in decimal degrees)
  """
  # convert decimal degrees to radians 
  lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

  # haversine formula 
  dlon = lon2 - lon1 
  dlat = lat2 - lat1 
  a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
  c = 2 * asin(sqrt(a)) 
  r = 6371 # Radius of earth in kilometers. Use 3956 for miles
  return c * r

def create_visited():
  visited_gages = {"stations_visited":{}, "saved_complete":{}}
  with open("visited_gages.json", "w+") as f:
    json.dump(visited_gages,f)

def get_weather_data(file_path:str, econet_gages:Set, base_url:str, visited_path:str):
  """
  Function that retrieves if station has weather 
  data for a specific gage either from ASOS or ECONet 
  """
  # Base URL "https://mesonet.agron.iastate.edu/cgi-bin/request/asos.py?station={}&data=tmpf&data=p01m&year1=2019&month1=1&day1=1&year2=2019&month2=1&day2=2&tz=Etc%2FUTC&format=onlycomma&latlon=no&missing=M&trace=T&direct=no&report_type=1&report_type=2"
  with open(visited_path, "r") as g:
    stations_explored = json.load(g)
  
  gage_meta_info = {}
  try:
    with open(file_path) as f:
      gage_data = json.load(f)
  except:
    print(file_path)
    return "Invalid"
  
  gage_meta_info["gage_id"] = gage_data["river_id"]
  gage_meta_info["stations"] = []
  closest_stations = gage_data["stations"][-20:]
  for station in reversed(closest_stations):
    if station["station_id"] in stations_explored["stations_visited"]:
      gage_meta_info["stations"].append({"station_id":station["station_id"], 
                                      "dist":station["dist"], "cat":"ASOS"})
      stations_explored["stations_visited"][str(station["station_id"])] = "True"
    else:
      url = base_url.format(station["station_id"])
      response = requests.get(url)
      if len(response.text)>100:
        gage_meta_info["stations"].append({"station_id":station["station_id"], 
                                          "dist":station["dist"], "cat":"ASOS"})
      elif station["station_id"] in econet_gages:
        gage_meta_info["stations"].append({"station_id":station["station_id"], 
                                          "dist":station["dist"], "cat":"ECO"})
  with open(visited_path, "w+") as c:
    json.dump(stations_explored, c)
  with open(file_path, "w+") as f:
    json.dump(gage_meta_info, f)

  return gage_meta_info

def format_dt(date_time_str:str) -> datetime:
  proper_datetime = datetime.strptime(date_time_str, "%Y-%m-%d %H:%M")
  if proper_datetime.minute != 0:
    proper_datetime = proper_datetime + timedelta(hours=1)
    proper_datetime = proper_datetime.replace(minute=0)
  return proper_datetime
    
def process_asos_data(file_path:str, base_url:str, stations_explored_path, client)->Dict:
  """
  Function that saves the ASOS data to CSV 
  uses output of get weather data.
  """
  station_meta_dict = {}
  with open (stations_explored_path) as g:
    stations_explored = json.load(g)
  with open(file_path) as f:
    gage_data = json.load(f)
    stations_list = []
    for station in gage_data["stations"]:
      if station["station_id"] in stations_explored["saved_complete"]:
        station1 = stations_explored["saved_complete"][station["station_id"]]
        station["missing_temp"] = station1["missing_temp"]
        station["missing_precip"] = station1["missing_precip"]
      elif station["cat"] == "ASOS" :
        response = requests.get(base_url.format(station["station_id"]))
        with open("temp_weather_data.csv", "w+") as f:
          f.write(response.text)
        df, missing_precip, missing_temp = process_asos_csv("temp_weather_data.csv")
        station["missing_precip"] = missing_precip
        station["missing_temp"] = missing_temp
        stations_explored["saved_complete"][str(station["station_id"])] = station
        df.to_csv(str(station["station_id"])+".csv")
        name = str(station["station_id"])+".csv"
        upload_file("predict_cfs",  "asos/" + name, name, client)
        station_meta_dict[station["station_id"]] = station
      stations_list.append(station)
    gage_data["stations"] = stations_list
    print(gage_data)
  with open(file_path, "w") as f:
    json.dump(gage_data, f)
  upload_file("predict_cfs", "meta_data/" + file_path, file_path, client)
  with open (stations_explored_path, "w+") as g:
    json.dump(stations_explored, g)
  upload_file("predict_cfs", "asos/" +"record.json", stations_explored_path, client)
  return gage_data

def process_asos_csv(path:str):
    df = pd.read_csv(path)
    missing_precip = df['p01m'][df['p01m']=='M'].count()
    missing_temp = df['tmpf'][df['tmpf']=='M'].count()
    df['hour_updated'] = df['valid'].map(format_dt)
    df['tmpf'] = pd.to_numeric(df['tmpf'], errors='coerce')
    
    df['p01m'] = pd.to_numeric(df['p01m'], errors='coerce')
    # Replace mising values with an average of the two closest values
    # Since stations record at different intervals this could 
    # actually cause an overestimation of precip. Instead replace with 0
    #df['p01m']=(df['p01m'].fillna(method='ffill') + df['p01m'].fillna(method='bfill'))/2
    df['p01m'] = df['p01m'].fillna(0)
    df['tmpf']=(df['tmpf'].fillna(method='ffill') + df['tmpf'].fillna(method='bfill'))/2
    df = df.groupby(by=['hour_updated'], as_index=False).agg({'p01m': 'sum', 'valid': 'first', 'tmpf': 'mean'})
    return df, int(missing_precip), int(missing_temp)

# %%
eco_gage_set = {'A', 'AURO', 'BEAR', 'BUCK', 'BURN', 'CAST', 'CLA2',
 'CLAY', 'CLIN', 'DURH', 'FLET', 'FRYI', 'GARM', 'GATH', 'GBAX', 'GBRA',
 'GBRE','GBYR','GCAM', 'GCHA', 'GCHS','GCML', 'GCOH', 'GCOO', 'GDAL',
 'GDAW','GDIN', 'GFTB','GLOU','GMCI','GMCR','GMET','GMID','GNEW',
 'GOCO', 'GOKE', 'GOLD', 'GPLA','GSTA','GSTE','GTAL','GTOC','GWAS',
 'GWAY', 'HAML', 'JACK', 'JEFF', 'K0A9', 'K1A5', 'K3J7', 'K6A1',
 'K6A2', 'KACJ',
 'KAFP',
 'KAIK',
 'KARW',
 'KASJ',
 'KAYS',
 'KBBP',
 'KBGE',
 'KBGF',
 'KBIJ',
 'KBNL',
 'KBQK',
 'KCCO',
 'KCDN',
 'KCKF',
 'KCKI',
 'KCNI',
 'KCPC',
 'KCQW',
 'KCTJ',
 'KCTZ',
 'KCWV',
 'KDBN',
 'KDCM',
 'KDNN',
 'KDPL',
 'KDQH',
 'KDYB',
 'KDYR',
 'KEDE',
 'KEHO',
 'KEOE',
 'KETC',
 'KEXX',
 'KEYF',
 'KEZM',
 'KFBG',
 'KFDW',
 'KFFA',
 'KFQD',
 'KGEV',
 'KGGE',
 'KGSB',
 'KGWW',
 'KGYH',
 'KHBI',
 'KHFF',
 'KHNZ',
 'KHOE',
 'KHQU',
 'KHRJ',
 'KHVS',
 'KHXD',
 'KHYW',
 'KIIY',
 'KINS',
 'KIPJ',
 'KISO',
 'KIXA',
 'KJES',
 'KJNX',
 'KJQF',
 'KJYL',
 'KJZI',
 'KLGC',
 'KLHW',
 'KLHZ',
 'KLKR',
 'KLQK',
 'KLRO',
 'KLSF',
 'KLUX',
 'KLZU',
 'KMAO',
 'KMGE',
 'KMGR',
 'KMKS',
 'KMLJ',
 'KMMI',
 'KMMT',
 'KMNI',
 'KMQI',
 'KMQY',
 'KMRN',
 'KMWK',
 'KMYR',
 'KNBC',
 'KNBT',
 'KNCA',
 'KNJM',
 'KNKT',
 'KNQA',
 'KOAJ',
 'KOCW',
 'KONX',
 'KOPN',
 'KPGV',
 'KPOB',
 'KRBW',
 'KRCZ',
 'KRHP',
 'KRUQ',
 'KRYY',
 'KSBO',
 'KSCR',
 'KSIF',
 'KSMS',
 'KSOP',
 'KSPA',
 'KSSC',
 'KSUT',
 'KSVH',
 'KSVN',
 'KTBR',
 'KTDF',
 'KTHA',
 'KTMA',
 'KTNB',
 'KTTA',
 'KTVI',
 'KUCY',
 'KUDG',
 'KUKF',
 'KVAD',
 'KVDI',
 'KVUJ',
 'KWDR',
 'KWRB',
 'LAKE',
 'LAUR',
 'LEWS',
 'LILE',
 'MITC',
 'N7MR',
 'NBAC',
 'NBFT',
 'NBUS',
 'NCAS',
 'NCAT',
 'NCDI',
 'NCHE',
 'NCOW',
 'NCRN',
 'NDAV',
 'NDBR',
 'NDUK',
 'NELI',
 'NEWL',
 'NFAI',
 'NFBR',
 'NFIN',
 'NGRC',
 'NGRF',
 'NGUI',
 'NHIG',
 'NHOF',
 'NJCY',
 'NJES',
 'NLEX',
 'NMTI',
 'NNAC',
 'NNCP',
 'NNWB',
 'NPOC',
 'NRAV',
 'NRCK',
 'NREN',
 'NRUT',
 'NSND',
 'NSUN',
 'NTUR',
 'NTUS',
 'NTYL',
 'NUWH',
 'NWAY',
 'NWHI',
 'OXFO',
 'PLYM',
 'REED',
 'REID',
 'ROCK',
 'SALI',
 'SANP',
 'SCAR',
 'SCON',
 'SILR',
 'SKIN',
 'SPRU',
 'SSAT',
 'SSAV',
 'SSV1',
 'SSV2',
 'SWHI',
 'SWIT',
 'Station_Metadata.txt',
 'TAYL',
 'TBIG',
 'TBLE',
 'TBUR',
 'TCAM',
 'TCHC',
 'TCHE',
 'TCHU',
 'TCOK',
 'TCRO',
 'TFCL',
 'THAM',
 'TIND',
 'TLEW',
 'TMEI',
 'TMER',
 'TPRE',
 'TSHI',
 'TTOW',
 'TWES',
 'WAYN',
 'WHIT',
 'WILD',
 'WILL',
 'WINE'}

# %%
from google.cloud import storage
def get_client():
  storage_client = storage.Client(project="gmap-997")
  print(storage_client.__dict__)
  # Make an authenticated API request
  buckets = list(storage_client.list_buckets())
  return storage_client

def build_dataset(json_full_path, asos_base_url, base_url_2, econet_data, visited_gages_path, start=0, end_index=100):
  directory = os.fsencode(json_full_path)
  sorted_list = sorted(os.listdir(directory))
  client = get_client()
  for i in range(start, end_index):
    file = sorted_list[i]
    filename = os.fsdecode(file)
    if get_weather_data(os.path.join(json_full_path, filename), econet_data, asos_base_url, visited_gages_path) != "Invalid":
      process_asos_data(os.path.join(json_full_path, filename), base_url_2, visited_gages_path, client)

# %%
def upload_file(bucket_name:str, file_name:str, upload_name:str, client):
    print(upload_name)
    bucket = client.get_bucket(bucket_name)
    blob = bucket.blob(file_name)
    blob.upload_from_filename(upload_name)

# %%
# !gsutil ls gs://predict_cfs/meta_data/distance3/** | wc -l
# !gsutil cp gs://predict_cfs/asos/record.json .
# !gsutil ls gs://predict_cfs/meta2 | wc -l
# !gsutil ls gs://predict_cfs/meta_data/gage_data | wc -l

#1138, 1139
# Out:
# 3880
# Copying gs://predict_cfs/asos/record.json...
# / [1 files][376.8 KiB/376.8 KiB]
# Operation completed over 1 objects/376.8 KiB.
# 1269
# 5171

# %%
# !gsutil ls gs://predict_cfs/meta3 | wc -l
# !gsutil ls gs://predict_cfs/joined2 | wc -l
# !gsutil ls gs://predict_cfs/joined | wc -l
# !gsutil ls gs://predict_cfs/joined5 | wc -l
# Out:
# 247
# 246
# 1266
# 596

# %%
base_url = "https://mesonet.agron.iastate.edu/cgi-bin/request/asos.py?station={}&data=tmpf&data=p01m&year1=2019&month1=1&day1=1&year2=2019&month2=1&day2=2&tz=Etc%2FUTC&format=onlycomma&latlon=no&missing=M&trace=T&direct=no&report_type=1&report_type=2"
base_url2 = "https://mesonet.agron.iastate.edu/cgi-bin/request/asos.py?station={}&data=tmpf&data=p01m&year1=2014&month1=1&day1=1&year2=2019&month2=1&day2=2&tz=Etc%2FUTC&format=onlycomma&latlon=no&missing=M&trace=T&direct=no&report_type=1&report_type=2"
build_dataset("gage_data",  base_url, base_url2, eco_gage_set, "record.json", 5998, 6052)
# Out:
# {'_base_connection': <google.cloud.storage._http.Connection object at 0x7f3ce3746b38>, 'project': 'gmap-997', '_credentials': <google.oauth2.credentials.Credentials object at 0x7f3cc0755cf8>, '_http_internal': None, '_batch_stack': <google.cloud._helpers._LocalStack object at 0x7f3cc0821b28>}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-06eef1c2bb70> in <module>()
#       1 base_url = "https://mesonet.agron.iastate.edu/cgi-bin/request/asos.py?station={}&data=tmpf&data=p01m&year1=2019&month1=1&day1=1&year2=2019&month2=1&day2=2&tz=Etc%2FUTC&format=onlycomma&latlon=no&missing=M&trace=T&direct=no&report_type=1&report_type=2"
#       2 base_url2 = "https://mesonet.agron.iastate.edu/cgi-bin/request/asos.py?station={}&data=tmpf&data=p01m&year1=2014&month1=1&day1=1&year2=2019&month2=1&day2=2&tz=Etc%2FUTC&format=onlycomma&latlon=no&missing=M&trace=T&direct=no&report_type=1&report_type=2"
# ----> 3 build_dataset("gage_data",  base_url, base_url2, eco_gage_set, "record.json", 5998, 6052)
#
# <ipython-input-7-6c7228b305e4> in build_dataset(json_full_path, asos_base_url, base_url_2, econet_data, visited_gages_path, start, end_index)
#      14     file = sorted_list[i]
#      15     filename = os.fsdecode(file)
# ---> 16     if get_weather_data(os.path.join(json_full_path, filename), econet_data, asos_base_url, visited_gages_path) != "Invalid":
#      17       process_asos_data(os.path.join(json_full_path, filename), base_url_2, visited_gages_path, client)
#      18
#
# <ipython-input-5-040ff8784651> in get_weather_data(file_path, econet_gages, base_url, visited_path)
#      77     else:
#      78       url = base_url.format(station["station_id"])
# ---> 79       response = requests.get(url)
#      80       if len(response.text)>100:
#      81         gage_meta_info["stations"].append({"station_id":station["station_id"],
#
# /usr/local/lib/python3.6/dist-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/local/lib/python3.6/dist-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/local/lib/python3.6/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.6/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1344         try:
#    1345             try:
# -> 1346                 response.begin()
#    1347             except ConnectionError:
#    1348                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# !ls
# Out:
# adc.json  gage_data  record.json  sample_data

# %%
# !ls distance3/gage_data
# Out:
# ls: cannot access 'distance3/gage_data': No such file or directory

# %%
# !gsutil -m cp  -r gs://predict_cfs/meta_data/distance3/ . 
# !gsutil -m cp -r gs://predict_cfs/asos .
# Out:
# Copying gs://predict_cfs/meta_data/distance3/1010000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1010070stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1013500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1010500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1014000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1011000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1015800stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1012960stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1017000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1017060stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1017290stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1017550stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1017960stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1018009stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1018035stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1018000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1018500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1021000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1019000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1021060stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1021200stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1021230stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1021452stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1021470stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1021480stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1021500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1022210stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1022220stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1022260stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1022294stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1022295stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1022330stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1022500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1022800stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1022835stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1022840stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1022860stations.json...
# Copying gs://predict_cfs/meta_data/distance3/102432241stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10243224stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10243240stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10243260stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10243700stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10244950stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10245445stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10245100stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10245900stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10245910stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10245925stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10245960stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10245970stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10246846stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10246835stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10246930stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10247200stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10249190stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10249280stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10249300stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10251217stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10251242stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10251248stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10251250stations.json...
# Copying gs://predict_cfs/meta_data/distance3/102512531stations.json...
# Copying gs://predict_cfs/meta_data/distance3/102512533stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1025125356stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1025125372stations.json...
# Copying gs://predict_cfs/meta_data/distance3/102512537stations.json...
# Copying gs://predict_cfs/meta_data/distance3/102512535stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10251255stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10251275stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10251890stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1027200stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1027240stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1029200stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10293048stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10293050stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10293500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10295000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1029500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10297010stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10297500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10298600stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10299100stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10299300stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1030000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10300000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10300600stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10300200stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10301115stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10301120stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10301290stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10301495stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10301500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10301600stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10301720stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10301742stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10301755stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10301745stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10301900stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10302002stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10302025stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10302145stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10302160stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1030350stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1030500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10308800stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10309000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10309010stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10309035stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10309050stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10309070stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10309100stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10310350stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10310358stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10310402stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10310403stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10310448stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10310500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10311000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10311090stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10311100stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10311200stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10311260stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10311300stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10311400stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10311700stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10311750stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10312000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10312150stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1031221775stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10312210stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1031221902stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10312250stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10312275stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10312277stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1031300stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10313400stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10313900stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1031450stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1031500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1031510stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10315500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10315600stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10316500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10317480stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10317500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10318500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10319900stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10320000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10320100stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10321000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10321590stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10321860stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10321925stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10321940stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10321950stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10321970stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10322000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10322150stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10322500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/103225055stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10322505stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10322535stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10322510stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10323425stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10322555stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10322800stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10324500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10324700stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10325000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10327500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10329000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10329500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1033000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10333000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10335000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10336000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10336698stations.json...
# Copying gs://predict_cfs/meta_data/distance3/103366993stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10336700stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10336715stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10336730stations.json...
# Copying gs://predict_cfs/meta_data/distance3/103367585stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10336740stations.json...
# Copying gs://predict_cfs/meta_data/distance3/103367592stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10336760stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10336765stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1034000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1034500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10347310stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10347460stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10347600stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10347620stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10348000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10348036stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10348200stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10348220stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10348245stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10348295stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10348300stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10348460stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10348550stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10348570stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10348850stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10348900stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10349300stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10349495stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10349849stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10349980stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10350000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10350340stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10350400stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10351300stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10351400stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10351600stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10351650stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10353600stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10353770stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1037380stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1038000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1042500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1043500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1044550stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1046000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1046500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1047000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1047150stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1047200stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1048000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1048220stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1049000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1049130stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1049205stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1049265stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1049320stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1049330stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1049373stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1049500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1049505stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1049550stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1052500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1053500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1053600stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1054000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1054114stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1054200stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1054300stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1054500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1055000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1055220stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1055500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1056400stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1056480stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1056505stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1057000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1059000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1059800stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1060000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1063100stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1063310stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1063452stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1064118stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10642505stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1064300stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1064485stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1064801stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1064500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1065500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1066000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1067851stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1067853stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1067950stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1068910stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1069500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1069700stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1072100stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1072800stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1072870stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1072880stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1073000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1073319stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1073500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10735562stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1073587stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1074520stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1075000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1076000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1073785stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1076500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1077400stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1078000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1081000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1081500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1082000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1085000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1084000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1085500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1086000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1089100stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1089925stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1089500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1091000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1091500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1092000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1093852stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1094000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1094500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1094400stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1095220stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1095375stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1095434stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1095503stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1096000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1096500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/10965852stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1097000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1097300stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1098500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1098530stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1099500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1100000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1100500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1100505stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1100561stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1100568stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1100600stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1100627stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1100693stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1100870stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1101000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1101500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1102000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1102345stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1102500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1103010stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1103025stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1103050stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1103280stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1103455stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1103500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104200stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104370stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104405stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104410stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104415stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104420stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104430stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104433stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104453stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104455stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104460stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104475stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104480stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104501stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104683stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104705stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1105500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/11055525stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1104715stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1105000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1105554stations.json...
# Copying gs://predict_cfs/meta_data/distance3/11055566stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1105583stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1105584stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1105585stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1105600stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1105606stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1105607stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1105608stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1105638stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1105730stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1105870stations.json...
# Copying gs://predict_cfs/meta_data/distance3/11058756stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1105876stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1105880stations.json...
# Copying gs://predict_cfs/meta_data/distance3/110588374stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1105883757stations.json...
# Copying gs://predict_cfs/meta_data/distance3/11058837stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1105917stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1105933stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1106500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1108000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1108320stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1108410stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1109000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1109060stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1109070stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1109090stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1109220stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1109439stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1109659stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1109730stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1109852stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1110000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1110095stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1110400stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1110500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1111208stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1111212stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1111225stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1111230stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1123360stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1123600stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1129200stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1129440stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1129500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1130000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1131500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1137500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1137940stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1141800stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1144500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1150500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1152500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1154500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1154950stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1157000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1158000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1158110stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1160000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1160350stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1161000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1161280stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1162000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1162500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1163200stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1166105stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1166500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1168151stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1168250stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1168500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1168639stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1168640stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1169000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1169900stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1170000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1170100stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1170500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1170930stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1171300stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1171500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1172003stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1172010stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1172500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1173000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1173500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1174500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1174565stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1174570stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1174575stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1174900stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1175500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1175670stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1176000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1176780stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1177000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1179500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1181000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1183500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1185500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1197000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1197500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1198000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1198125stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12301250stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12301300stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12301933stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12302055stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12303500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12304040stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12304500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12305000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12323170stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12323240stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12323248stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12323250stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12323600stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12323670stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12323700stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12323710stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12323720stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12323750stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12323770stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12323760stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12323800stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12323840stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12323850stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12324200stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12324400stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12324590stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12324680stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12325500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12326420stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12327090stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12327100stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12328500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12330000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12329500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12331100stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12331500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12331590stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12331620stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12331800stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12331900stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12334510stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12332000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12334550stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12335100stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12335500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12337800stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12338100stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12338300stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12339450stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12340500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12340000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12342500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12343300stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12343400stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12344000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12346500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12350250stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12351200stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12352500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12353000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12354000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12354500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12355342stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12355347stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12355500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12357800stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12358500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12359800stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12362500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12363000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12365000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12365700stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12366000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12366080stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12366500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12369000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12369200stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12369650stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12370000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12372000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12374250stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12375900stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12377150stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12381400stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12383500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12387450stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12388200stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12388400stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12388700stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12389000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12389500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/12390700stations.json...
# Copying gs://predict_cfs/meta_data/distance3/13105000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/13161500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/13162225stations.json...
# Copying gs://predict_cfs/meta_data/distance3/13174500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/13175100stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1331500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1332500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1333000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1367690stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1367715stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1367800stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1367805stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1377000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1377370stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1377451stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1377500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1378500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1379000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1379500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1379530stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1379699stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1379773stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1379780stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1379845stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1379868stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1380000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1380100stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1380450stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1380500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1381000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1381400stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1381500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1381800stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1381900stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1381940stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1382170stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1382210stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1382270stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1382385stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1382500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1382800stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1383500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1386000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1384500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1384000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1387000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1387500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1387905stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1387908stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1387940stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1388000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1388100stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1388500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1388700stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1388910stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1389005stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1389010stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1389492stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1389500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1389534stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1389550stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1389765stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1389802stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1389890stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1390450stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1390500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1391000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1391102stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1391500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1392170stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1392210stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1392500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1393450stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1393890stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1393895stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1394000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1394500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1394620stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1395000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1396000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1396001stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1396091stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1396152stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1396190stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1396500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1396580stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1396582stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1396660stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1397000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1396800stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1397420stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1398000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1398045stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1398102stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1398107stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1398500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1398900stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1399100stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1399190stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1399200stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1399500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1399510stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1399525stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1399670stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1399700stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1399780stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1399830stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1400010stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1400000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1400300stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1400350stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1400360stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1400500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1400730stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1401000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1401301stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1401650stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1401750stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1402000stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1402500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1402540stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1402600stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1402630stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1403060stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1403150stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1403160stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1403200stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1403400stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1403500stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1403535stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1403540stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1403570stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1403600stations.json...
# Copying gs://predict_cfs/meta_data/distance3/1403900stations.json...
# ...
# Copying gs://predict_cfs/asos/PPO.csv...
# Copying gs://predict_cfs/asos/PPF.csv...
# Copying gs://predict_cfs/asos/PPQ.csv...
# Copying gs://predict_cfs/asos/PQI.csv...
# Copying gs://predict_cfs/asos/PQL.csv...
# Copying gs://predict_cfs/asos/PQN.csv...
# Copying gs://predict_cfs/asos/PRS.csv...
# Copying gs://predict_cfs/asos/PRX.csv...
# Copying gs://predict_cfs/asos/PSC.csv...
# Copying gs://predict_cfs/asos/PSF.csv...
# Copying gs://predict_cfs/asos/PSK.csv...
# Copying gs://predict_cfs/asos/PSM.csv...
# Copying gs://predict_cfs/asos/PSN.csv...
# Copying gs://predict_cfs/asos/PSO.csv...
# Copying gs://predict_cfs/asos/PSX.csv...
# Copying gs://predict_cfs/asos/PTB.csv...
# Copying gs://predict_cfs/asos/PTD.csv...
# Copying gs://predict_cfs/asos/PTK.csv...
# Copying gs://predict_cfs/asos/PTS.csv...
# Copying gs://predict_cfs/asos/PTN.csv...
# Copying gs://predict_cfs/asos/PTT.csv...
# Copying gs://predict_cfs/asos/PTW.csv...
# Copying gs://predict_cfs/asos/PUC.csv...
# Copying gs://predict_cfs/asos/PUW.csv...
# Copying gs://predict_cfs/asos/PVB.csv...
# Copying gs://predict_cfs/asos/PVC.csv...
# Copying gs://predict_cfs/asos/PVD.csv...
# Copying gs://predict_cfs/asos/PVE.csv...
# Copying gs://predict_cfs/asos/PVG.csv...
# Copying gs://predict_cfs/asos/PVU.csv...
# Copying gs://predict_cfs/asos/PVW.csv...
# Copying gs://predict_cfs/asos/PWA.csv...
# Copying gs://predict_cfs/asos/PWC.csv...
# Copying gs://predict_cfs/asos/PWG.csv...
# Copying gs://predict_cfs/asos/PWK.csv...
# Copying gs://predict_cfs/asos/PWM.csv...
# Copying gs://predict_cfs/asos/PWT.csv...
# Copying gs://predict_cfs/asos/PYM.csv...
# Copying gs://predict_cfs/asos/PYX.csv...
# Copying gs://predict_cfs/asos/PZQ.csv...
# Copying gs://predict_cfs/asos/RAC.csv...
# Copying gs://predict_cfs/asos/RAP.csv...
# Copying gs://predict_cfs/asos/RAS.csv...
# Copying gs://predict_cfs/asos/RAW.csv...
# Copying gs://predict_cfs/asos/RBD.csv...
# Copying gs://predict_cfs/asos/RBG.csv...
# Copying gs://predict_cfs/asos/RBW.csv...
# Copying gs://predict_cfs/asos/RCA.csv...
# Copying gs://predict_cfs/asos/RCE.csv...
# Copying gs://predict_cfs/asos/RCM.csv...
# Copying gs://predict_cfs/asos/RCV.csv...
# Copying gs://predict_cfs/asos/RCX.csv...
# Copying gs://predict_cfs/asos/RCZ.csv...
# Copying gs://predict_cfs/asos/RDG.csv...
# Copying gs://predict_cfs/asos/RDM.csv...
# Copying gs://predict_cfs/asos/RDR.csv...
# Copying gs://predict_cfs/asos/RDU.csv...
# Copying gs://predict_cfs/asos/REG.csv...
# Copying gs://predict_cfs/asos/REO.csv...
# Copying gs://predict_cfs/asos/RFD.csv...
# Copying gs://predict_cfs/asos/RFI.csv...
# Copying gs://predict_cfs/asos/RGK.csv...
# Copying gs://predict_cfs/asos/RHI.csv...
# Copying gs://predict_cfs/asos/RHP.csv...
# Copying gs://predict_cfs/asos/RIC.csv...
# Copying gs://predict_cfs/asos/RID.csv...
# Copying gs://predict_cfs/asos/RIW.csv...
# Copying gs://predict_cfs/asos/RKD.csv...
# Copying gs://predict_cfs/asos/RKP.csv...
# Copying gs://predict_cfs/asos/RKR.csv...
# Copying gs://predict_cfs/asos/RKW.csv...
# Copying gs://predict_cfs/asos/RKS.csv...
# Copying gs://predict_cfs/asos/RLD.csv...
# Copying gs://predict_cfs/asos/RME.csv...
# Copying gs://predict_cfs/asos/RMN.csv...
# Copying gs://predict_cfs/asos/RMY.csv...
# Copying gs://predict_cfs/asos/RNC.csv...
# Copying gs://predict_cfs/asos/RND.csv...
# Copying gs://predict_cfs/asos/RNH.csv...
# Copying gs://predict_cfs/asos/RNO.csv...
# Copying gs://predict_cfs/asos/RNP.csv...
# Copying gs://predict_cfs/asos/RNT.csv...
# Copying gs://predict_cfs/asos/RNV.csv...
# Copying gs://predict_cfs/asos/ROA.csv...
# Copying gs://predict_cfs/asos/ROC.csv...
# Copying gs://predict_cfs/asos/ROG.csv...
# Copying gs://predict_cfs/asos/ROS.csv...
# Copying gs://predict_cfs/asos/ROW.csv...
# Copying gs://predict_cfs/asos/ROX.csv...
# Copying gs://predict_cfs/asos/RPD.csv...
# Copying gs://predict_cfs/asos/RPH.csv...
# Copying gs://predict_cfs/asos/RPJ.csv...
# Copying gs://predict_cfs/asos/RQB.csv...
# Copying gs://predict_cfs/asos/RQE.csv...
# Copying gs://predict_cfs/asos/RQO.csv...
# Copying gs://predict_cfs/asos/RRL.csv...
# Copying gs://predict_cfs/asos/RRT.csv...
# Copying gs://predict_cfs/asos/RSL.csv...
# Copying gs://predict_cfs/asos/RSN.csv...
# Copying gs://predict_cfs/asos/RST.csv...
# Copying gs://predict_cfs/asos/RTN.csv...
# Copying gs://predict_cfs/asos/RTS.csv...
# Copying gs://predict_cfs/asos/RUG.csv...
# Copying gs://predict_cfs/asos/RUQ.csv...
# Copying gs://predict_cfs/asos/RUT.csv...
# Copying gs://predict_cfs/asos/RVS.csv...
# Copying gs://predict_cfs/asos/RWF.csv...
# Copying gs://predict_cfs/asos/RWI.csv...
# Copying gs://predict_cfs/asos/RWL.csv...
# Copying gs://predict_cfs/asos/RWV.csv...
# Copying gs://predict_cfs/asos/RXE.csv...
# Copying gs://predict_cfs/asos/RYM.csv...
# Copying gs://predict_cfs/asos/RYV.csv...
# Copying gs://predict_cfs/asos/RYW.csv...
# Copying gs://predict_cfs/asos/RZN.csv...
# Copying gs://predict_cfs/asos/RZR.csv...
# Copying gs://predict_cfs/asos/RZT.csv...
# Copying gs://predict_cfs/asos/S25.csv...
# Copying gs://predict_cfs/asos/S32.csv...
# Copying gs://predict_cfs/asos/S33.csv...
# Copying gs://predict_cfs/asos/S39.csv...
# Copying gs://predict_cfs/asos/S52.csv...
# Copying gs://predict_cfs/asos/SAA.csv...
# Copying gs://predict_cfs/asos/SAD.csv...
# Copying gs://predict_cfs/asos/SAF.csv...
# Copying gs://predict_cfs/asos/SAR.csv...
# Copying gs://predict_cfs/asos/SAT.csv...
# Copying gs://predict_cfs/asos/SAV.csv...
# Copying gs://predict_cfs/asos/SAW.csv...
# Copying gs://predict_cfs/asos/SAZ.csv...
# Copying gs://predict_cfs/asos/SBM.csv...
# Copying gs://predict_cfs/asos/SBS.csv...
# Copying gs://predict_cfs/asos/SBN.csv...
# Copying gs://predict_cfs/asos/SBY.csv...
# Copying gs://predict_cfs/asos/SCAR.csv...
# Copying gs://predict_cfs/asos/SCF.csv...
# Copying gs://predict_cfs/asos/SCH.csv...
# Copying gs://predict_cfs/asos/SCR.csv...
# Copying gs://predict_cfs/asos/SDC.csv...
# Copying gs://predict_cfs/asos/SDF.csv...
# Copying gs://predict_cfs/asos/SDY.csv...
# Copying gs://predict_cfs/asos/SEA.csv...
# Copying gs://predict_cfs/asos/SEG.csv...
# Copying gs://predict_cfs/asos/SEP.csv...
# Copying gs://predict_cfs/asos/SET.csv...
# Copying gs://predict_cfs/asos/SFF.csv...
# Copying gs://predict_cfs/asos/SFM.csv...
# Copying gs://predict_cfs/asos/SFQ.csv...
# Copying gs://predict_cfs/asos/SFY.csv...
# Copying gs://predict_cfs/asos/SFZ.csv...
# Copying gs://predict_cfs/asos/SGF.csv...
# Copying gs://predict_cfs/asos/SGH.csv...
# Copying gs://predict_cfs/asos/SGR.csv...
# Copying gs://predict_cfs/asos/SGS.csv...
# Copying gs://predict_cfs/asos/SGT.csv...
# Copying gs://predict_cfs/asos/SGU.csv...
# Copying gs://predict_cfs/asos/SHD.csv...
# Copying gs://predict_cfs/asos/SHN.csv...
# Copying gs://predict_cfs/asos/SHR.csv...
# Copying gs://predict_cfs/asos/SHV.csv...
# Copying gs://predict_cfs/asos/SIF.csv...
# Copying gs://predict_cfs/asos/SIK.csv...
# Copying gs://predict_cfs/asos/SIY.csv...
# Copying gs://predict_cfs/asos/SJS.csv...
# Copying gs://predict_cfs/asos/SJN.csv...
# Copying gs://predict_cfs/asos/SJT.csv...
# Copying gs://predict_cfs/asos/SJX.csv...
# Copying gs://predict_cfs/asos/SKA.csv...
# Copying gs://predict_cfs/asos/SKF.csv...
# Copying gs://predict_cfs/asos/SKX.csv...
# Copying gs://predict_cfs/asos/SLC.csv...
# Copying gs://predict_cfs/asos/SLE.csv...
# Copying gs://predict_cfs/asos/SLG.csv...
# Copying gs://predict_cfs/asos/SLH.csv...
# Copying gs://predict_cfs/asos/SLK.csv...
# Copying gs://predict_cfs/asos/SLN.csv...
# Copying gs://predict_cfs/asos/SLR.csv...
# Copying gs://predict_cfs/asos/SME.csv...
# Copying gs://predict_cfs/asos/SMN.csv...
# Copying gs://predict_cfs/asos/SMP.csv...
# Copying gs://predict_cfs/asos/SMQ.csv...
# Copying gs://predict_cfs/asos/SMS.csv...
# Copying gs://predict_cfs/asos/SNC.csv...
# Copying gs://predict_cfs/asos/SNH.csv...
# Copying gs://predict_cfs/asos/SNK.csv...
# Copying gs://predict_cfs/asos/SNL.csv...
# Copying gs://predict_cfs/asos/SNY.csv...
# Copying gs://predict_cfs/asos/SOA.csv...
# Copying gs://predict_cfs/asos/SOP.csv...
# Copying gs://predict_cfs/asos/SOW.csv...
# Copying gs://predict_cfs/asos/SPA.csv...
# Copying gs://predict_cfs/asos/SPB.csv...
# Copying gs://predict_cfs/asos/SPD.csv...
# Copying gs://predict_cfs/asos/SPF.csv...
# Copying gs://predict_cfs/asos/SPRU.csv...
# Copying gs://predict_cfs/asos/SPS.csv...
# Copying gs://predict_cfs/asos/SPW.csv...
# Copying gs://predict_cfs/asos/SRB.csv...
# Copying gs://predict_cfs/asos/SRE.csv...
# Copying gs://predict_cfs/asos/SRR.csv...
# Copying gs://predict_cfs/asos/SSC.csv...
# Copying gs://predict_cfs/asos/SSF.csv...
# Copying gs://predict_cfs/asos/STC.csv...
# Copying gs://predict_cfs/asos/STE.csv...
# Copying gs://predict_cfs/asos/STF.csv...
# Copying gs://predict_cfs/asos/STJ.csv...
# Copying gs://predict_cfs/asos/STK.csv...
# Copying gs://predict_cfs/asos/STL.csv...
# Copying gs://predict_cfs/asos/STP.csv...
# Copying gs://predict_cfs/asos/SUE.csv...
# Copying gs://predict_cfs/asos/SUS.csv...
# Copying gs://predict_cfs/asos/SUT.csv...
# Copying gs://predict_cfs/asos/SUW.csv...
# Copying gs://predict_cfs/asos/SUX.csv...
# Copying gs://predict_cfs/asos/SVC.csv...
# Copying gs://predict_cfs/asos/SVH.csv...
# Copying gs://predict_cfs/asos/SVN.csv...
# Copying gs://predict_cfs/asos/SWF.csv...
# Copying gs://predict_cfs/asos/SWO.csv...
# Copying gs://predict_cfs/asos/SXT.csv...
# Copying gs://predict_cfs/asos/SWW.csv...
# Copying gs://predict_cfs/asos/SXU.csv...
# Copying gs://predict_cfs/asos/SYF.csv...
# Copying gs://predict_cfs/asos/SYI.csv...
# Copying gs://predict_cfs/asos/SYM.csv...
# Copying gs://predict_cfs/asos/SYN.csv...
# Copying gs://predict_cfs/asos/SYR.csv...
# Copying gs://predict_cfs/asos/SZL.csv...
# Copying gs://predict_cfs/asos/SZT.csv...
# Copying gs://predict_cfs/asos/SZY.csv...
# Copying gs://predict_cfs/asos/T20.csv...
# Copying gs://predict_cfs/asos/T35.csv...
# Copying gs://predict_cfs/asos/T70.csv...
# Copying gs://predict_cfs/asos/T82.csv...
# Copying gs://predict_cfs/asos/TAD.csv...
# Copying gs://predict_cfs/asos/TAN.csv...
# Copying gs://predict_cfs/asos/TBN.csv...
# Copying gs://predict_cfs/asos/TBR.csv...
# Copying gs://predict_cfs/asos/TBX.csv...
# Copying gs://predict_cfs/asos/TCC.csv...
# Copying gs://predict_cfs/asos/TCL.csv...
# Copying gs://predict_cfs/asos/TCM.csv...
# Copying gs://predict_cfs/asos/TCS.csv...
# Copying gs://predict_cfs/asos/TDF.csv...
# Copying gs://predict_cfs/asos/TDZ.csv...
# Copying gs://predict_cfs/asos/TEB.csv...
# Copying gs://predict_cfs/asos/TEW.csv...
# Copying gs://predict_cfs/asos/TFP.csv...
# Copying gs://predict_cfs/asos/TGI.csv...
# Copying gs://predict_cfs/asos/THA.csv...
# Copying gs://predict_cfs/asos/THV.csv...
# Copying gs://predict_cfs/asos/TIF.csv...
# Copying gs://predict_cfs/asos/TIK.csv...
# Copying gs://predict_cfs/asos/TIW.csv...
# Copying gs://predict_cfs/asos/TKC.csv...
# Copying gs://predict_cfs/asos/TKI.csv...
# Copying gs://predict_cfs/asos/TKV.csv...
# Copying gs://predict_cfs/asos/TKX.csv...
# Copying gs://predict_cfs/asos/TME.csv...
# Copying gs://predict_cfs/asos/TMK.csv...
# Copying gs://predict_cfs/asos/TNB.csv...
# Copying gs://predict_cfs/asos/TOB.csv...
# Copying gs://predict_cfs/asos/TOC.csv...
# Copying gs://predict_cfs/asos/TOL.csv...
# Copying gs://predict_cfs/asos/TOP.csv...
# Copying gs://predict_cfs/asos/TOR.csv...
# Copying gs://predict_cfs/asos/TPH.csv...
# Copying gs://predict_cfs/asos/TPL.csv...
# Copying gs://predict_cfs/asos/TQE.csv...
# Copying gs://predict_cfs/asos/TQH.csv...
# Copying gs://predict_cfs/asos/TRI.csv...
# Copying gs://predict_cfs/asos/TRK.csv...
# Copying gs://predict_cfs/asos/TRL.csv...
# Copying gs://predict_cfs/asos/TTA.csv...
# Copying gs://predict_cfs/asos/TTD.csv...
# Copying gs://predict_cfs/asos/TTF.csv...
# Copying gs://predict_cfs/asos/TTN.csv...
# Copying gs://predict_cfs/asos/TUL.csv...
# Copying gs://predict_cfs/asos/TUP.csv...
# Copying gs://predict_cfs/asos/TVC.csv...
# Copying gs://predict_cfs/asos/TVF.csv...
# Copying gs://predict_cfs/asos/TVL.csv...
# Copying gs://predict_cfs/asos/TVR.csv...
# Copying gs://predict_cfs/asos/TVY.csv...
# Copying gs://predict_cfs/asos/TWF.csv...
# Copying gs://predict_cfs/asos/TWM.csv...
# Copying gs://predict_cfs/asos/TXK.csv...
# Copying gs://predict_cfs/asos/TYR.csv...
# Copying gs://predict_cfs/asos/TXW.csv...
# Copying gs://predict_cfs/asos/TYS.csv...
# Copying gs://predict_cfs/asos/TZR.csv...
# Copying gs://predict_cfs/asos/U16.csv...
# Copying gs://predict_cfs/asos/U42.csv...
# Copying gs://predict_cfs/asos/U68.csv...
# Copying gs://predict_cfs/asos/UAO.csv...
# Copying gs://predict_cfs/asos/UBE.csv...
# Copying gs://predict_cfs/asos/UCP.csv...
# Copying gs://predict_cfs/asos/UCY.csv...
# Copying gs://predict_cfs/asos/UDG.csv...
# Copying gs://predict_cfs/asos/UES.csv...
# Copying gs://predict_cfs/asos/UGN.csv...
# Copying gs://predict_cfs/asos/UIL.csv...
# Copying gs://predict_cfs/asos/UIN.csv...
# Copying gs://predict_cfs/asos/UKF.csv...
# Copying gs://predict_cfs/asos/UKT.csv...
# Copying gs://predict_cfs/asos/ULM.csv...
# Copying gs://predict_cfs/asos/ULS.csv...
# Copying gs://predict_cfs/asos/UNI.csv...
# Copying gs://predict_cfs/asos/UNO.csv...
# Copying gs://predict_cfs/asos/UNU.csv...
# Copying gs://predict_cfs/asos/UNV.csv...
# Copying gs://predict_cfs/asos/USE.csv...
# Copying gs://predict_cfs/asos/UOX.csv...
# Copying gs://predict_cfs/asos/UTA.csv...
# Copying gs://predict_cfs/asos/UTFF.csv...
# Copying gs://predict_cfs/asos/UTS.csv...
# Copying gs://predict_cfs/asos/UUU.csv...
# Copying gs://predict_cfs/asos/UVA.csv...
# Copying gs://predict_cfs/asos/UXL.csv...
# Copying gs://predict_cfs/asos/UYF.csv...
# Copying gs://predict_cfs/asos/UZA.csv...
# Copying gs://predict_cfs/asos/VAY.csv...
# Copying gs://predict_cfs/asos/VBT.csv...
# Copying gs://predict_cfs/asos/VBW.csv...
# Copying gs://predict_cfs/asos/VCT.csv...
# Copying gs://predict_cfs/asos/VEL.csv...
# Copying gs://predict_cfs/asos/VER.csv...
# Copying gs://predict_cfs/asos/VES.csv...
# Copying gs://predict_cfs/asos/VGT.csv...
# Copying gs://predict_cfs/asos/VIH.csv...
# Copying gs://predict_cfs/asos/VJI.csv...
# Copying gs://predict_cfs/asos/VKS.csv...
# Copying gs://predict_cfs/asos/VLL.csv...
# Copying gs://predict_cfs/asos/VOK.csv...
# Copying gs://predict_cfs/asos/VPZ.csv...
# Copying gs://predict_cfs/asos/VSF.csv...
# Copying gs://predict_cfs/asos/VTA.csv...
# Copying gs://predict_cfs/asos/VTN.csv...
# Copying gs://predict_cfs/asos/VUJ.csv...
# Copying gs://predict_cfs/asos/VUO.csv...
# Copying gs://predict_cfs/asos/VVV.csv...
# Copying gs://predict_cfs/asos/VWU.csv...
# Copying gs://predict_cfs/asos/W13.csv...
# Copying gs://predict_cfs/asos/W22.csv...
# Copying gs://predict_cfs/asos/W29.csv...
# Copying gs://predict_cfs/asos/W31.csv...
# Copying gs://predict_cfs/asos/W43.csv...
# Copying gs://predict_cfs/asos/W63.csv...
# Copying gs://predict_cfs/asos/W75.csv...
# Copying gs://predict_cfs/asos/W78.csv...
# Copying gs://predict_cfs/asos/W81.csv...
# Copying gs://predict_cfs/asos/W99.csv...
# Copying gs://predict_cfs/asos/W96.csv...
# Copying gs://predict_cfs/asos/WAL.csv...
# Copying gs://predict_cfs/asos/WDG.csv...
# Copying gs://predict_cfs/asos/WLD.csv...
# Copying gs://predict_cfs/asos/WMC.csv...
# Copying gs://predict_cfs/asos/WRI.csv...
# Copying gs://predict_cfs/asos/WRL.csv...
# Copying gs://predict_cfs/asos/WST.csv...
# Copying gs://predict_cfs/asos/WVL.csv...
# Copying gs://predict_cfs/asos/WWD.csv...
# Copying gs://predict_cfs/asos/WWR.csv...
# Copying gs://predict_cfs/asos/WYS.csv...
# Copying gs://predict_cfs/asos/XBP.csv...
# Copying gs://predict_cfs/asos/XLL.csv...
# Copying gs://predict_cfs/asos/XNA.csv...
# Copying gs://predict_cfs/asos/XNO.csv...
# Copying gs://predict_cfs/asos/XNX.csv...
# Copying gs://predict_cfs/asos/XPY.csv...
# Copying gs://predict_cfs/asos/XSA.csv...
# Copying gs://predict_cfs/asos/XVG.csv...
# Copying gs://predict_cfs/asos/Y19.csv...
# Copying gs://predict_cfs/asos/Y23.csv...
# Copying gs://predict_cfs/asos/Y31.csv...
# Copying gs://predict_cfs/asos/Y49.csv...
# Copying gs://predict_cfs/asos/Y50.csv...
# Copying gs://predict_cfs/asos/Y51.csv...
# Copying gs://predict_cfs/asos/Y63.csv...
# Copying gs://predict_cfs/asos/Y70.csv...
# Copying gs://predict_cfs/asos/YIP.csv...
# Copying gs://predict_cfs/asos/YKM.csv...
# Copying gs://predict_cfs/asos/YKN.csv...
# Copying gs://predict_cfs/asos/YNG.csv...
# Copying gs://predict_cfs/asos/ZZV.csv...
# Copying gs://predict_cfs/asos/record.json...
# / [3.3k/3.3k files][  7.2 GiB/  7.2 GiB] 100% Done  34.3 MiB/s ETA 00:00:00
# Operation completed over 3.3k objects/7.2 GiB.

# %%
import pandas as pd 
import requests 
from datetime import datetime
from typing import Tuple, Dict
# url format 
def make_usgs_data(start_date:datetime, end_date:datetime, site_number:str):
    base_url = "https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&"
    full_url = base_url + "site_no=" + site_number + "&period=&begin_date="+start_date.strftime("%Y-%m-%d") + "&end_date="+end_date.strftime("%Y-%m-%d")
    print("Getting request from USGS")
    print(full_url)
    r = requests.get(full_url)
    with open(site_number + ".txt", "w") as f:
        f.write(r.text)
    print("Request finished")
    response_data = process_response_text(site_number + ".txt")
    create_csv(response_data[0], response_data[1], site_number)
    return pd.read_csv(site_number + "_flow_data.csv")

def process_response_text(file_name:str)->Tuple[str, Dict]:
    extractive_params = {}
    with open(file_name, "r") as f: 
        lines = f.readlines()
        i = 0 
        params = False 
        while "#" in lines[i]:
            # TODO figure out getting height and discharge code efficently
            the_split_line = lines[i].split()[1:]
            if params:
                print(the_split_line)
                if len(the_split_line)<2:
                    params = False 
                else:
                    extractive_params[the_split_line[0]+"_"+the_split_line[1]] = df_label(the_split_line[2])
            if len(the_split_line)>2:
                if the_split_line[0]== "TS":
                    params = True
            i+=1
        with open(file_name.split(".")[0] + "data.tsv", "w") as t:
            t.write("".join(lines[i:]))
        return file_name.split(".")[0] + "data.tsv", extractive_params

def df_label(usgs_text:str)->str:
    usgs_text = usgs_text.replace(",","")
    if usgs_text == "Discharge":
        return "cfs"
    elif usgs_text=="Gage":
        return "height"
    else: 
        return usgs_text

def create_csv(file_path:str, params_names:dict, site_number:str):
    """
    Function that creates the final version of the CSV file
    Assigns 
    """
    print(params_names)
    df = pd.read_csv(file_path, sep="\t")
    for key, value in params_names.items():
        df[value] = df[key]
    df.to_csv(site_number + "_flow_data.csv")

# %%
timezone_map = {"EST": "America/New_York", "EDT":"America/New_York", "CST":"America/Chicago", "CDT":"America/Chicago", "MDT":"America/Denver", "MST":"America/Denver",
                "PST": "America/Los_Angeles", "PDT": "America/Los_Angeles"}

# %%
from datetime import datetime
import os 
  
def create_usgs(meta_data_dir:str, precip_path:str, start, end):
  gage_list = sorted(os.listdir(meta_data_dir))
  exceptions = {} 
  client = get_client()
  for i in range(start, end):
    try:
      file_name = gage_list[i]
      gage_id = file_name.split("stations")[0]
      with open(os.path.join(meta_data_dir , file_name)) as f:
        print(os.path.join(meta_data_dir , file_name))
        data = json.load(f)
      if len(gage_id) == 7:
        gage_id = "0"+gage_id
        raw_df = make_usgs_data(datetime(2014, 1, 1), datetime(2019,1,1), gage_id)
      else: 
        raw_df = make_usgs_data(datetime(2014, 1, 1), datetime(2019,1,1), gage_id)
      df, max_flow, min_flow = process_intermediate_csv(raw_df)
      data["time_zone_code"] = df["tz_cd"].iloc[0]
      data["max_flow"] = max_flow
      data["min_flow"] = min_flow
      precip_df = pd.read_csv(os.path.join(precip_path, data["stations"][0]["station_id"] + ".csv"))
      fixed_df, nan_flow, nan_precip = combine_data(df, precip_df)
      data["nan_flow"] = nan_flow
      data["nan_precip"] = nan_precip
      joined_name = str(gage_id) + data["stations"][0]["station_id"] + "_flow.csv"
      joined_upload = "joined5/" + joined_name
      meta_path = os.path.join(meta_data_dir , file_name)
      data["files"] = [joined_name]
      fixed_df.to_csv(joined_name)
      with open(meta_path, 'w') as f:
        json.dump(data, f)
      upload_file("predict_cfs", "meta4/" + file_name, meta_path, client)
      upload_file("predict_cfs", joined_upload, joined_name, client)
    except Exception as e:
      exceptions[str(gage_id)] = str(e)
      with open("exceptions10.json", "w+") as a:
        json.dump(exceptions, a)
      print("exception")
      print(e)
      upload_file("predict_cfs", "meta4/" + "exceptions10.json", "exceptions10.json", client)


def combine_data(flow_df, precip_df):
  tz = pytz.timezone("UTC")
  precip_df['hour_updated'] = precip_df['hour_updated'].map(lambda x: datetime.strptime(x, "%Y-%m-%d %H:%M:%S"))
  precip_df['hour_updated'] = precip_df['hour_updated'].map(lambda x: tz.localize(x))
  joined_df = precip_df.merge(flow_df, left_on='hour_updated', right_on='datetime', how='outer')[5:-5]
  nan_precip = sum(pd.isnull(joined_df['p01m']))
  nan_flow = sum(pd.isnull(joined_df['cfs']))
  return joined_df, nan_flow, nan_precip

# %%
import pytz
from typing import Tuple
def process_intermediate_csv(df:pd.DataFrame) -> (pd.DataFrame, int, int, int):
  # Remove garbage first row
  # TODO check if more rows are garabage
  df = df.iloc[1:]
  time_zone = df["tz_cd"].iloc[0]
  time_zone = timezone_map[time_zone]
  old_timezone = pytz.timezone(time_zone)
  new_timezone = pytz.timezone("UTC")
  # This assumes timezones are consistent throughout the USGS stream (this should be true)
  df["datetime"] = df["datetime"].map(lambda x: old_timezone.localize(datetime.strptime(x, "%Y-%m-%d %H:%M")).astimezone(new_timezone))
  df["cfs"] = pd.to_numeric(df['cfs'], errors='coerce')
  max_flow = df["cfs"].max()
  min_flow = df["cfs"].min()
  count_nan = len(df["cfs"]) - df["cfs"].count()
  return df[df.datetime.dt.minute==0], max_flow, min_flow

# %%
import json
create_usgs("distance3", "asos", 2600, 3000)
#df['hour_updated'] = df['hour_updated'].map(lambda x: datetime.strptime(x, "%Y-%m-%d %H:%M:%S"))
#tz = pytz.timezone("UTC")
#df['hour_updated'] = df['hour_updated'].map(lambda x: tz.localize(x))
# Out:
# {'_base_connection': <google.cloud.storage._http.Connection object at 0x7f3cc02110b8>, 'project': 'gmap-997', '_credentials': <google.oauth2.credentials.Credentials object at 0x7f3cc0116b70>, '_http_internal': None, '_batch_stack': <google.cloud._helpers._LocalStack object at 0x7f3cc01a5048>}
# distance3/7148111stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07148111&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57742', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57742_00060': 'cfs'}
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DtypeWarning: Columns (1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (2,5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# distance3/7148111stations.json
# 07148111KWLD_flow.csv
# distance3/7149000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07149000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57749', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57749_00060': 'cfs'}
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DtypeWarning: Columns (1,4) have mixed types. Specify dtype option on import or set low_memory=False.
# distance3/7149000stations.json
# 07149000P28_flow.csv
# distance3/7151500stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07151500&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57757', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57757_00060': 'cfs'}
# distance3/7151500stations.json
# 07151500KBKN_flow.csv
# distance3/7155590stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07155590&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['244999', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'244999_00060': 'cfs'}
# distance3/7155590stations.json
# 07155590EHA_flow.csv
# distance3/7156220stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07156220&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['212908', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'212908_00060': 'cfs'}
# exception
# '212908_00060'
# exceptions10.json
# distance3/7156900stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07156900&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['112081', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'112081_00060': 'cfs'}
# distance3/7156900stations.json
# 07156900LBL_flow.csv
# distance3/7157500stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07157500&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57765', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57765_00060': 'cfs'}
# distance3/7157500stations.json
# 07157500LBL_flow.csv
# distance3/7157740stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07157740&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57772', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57772_00060': 'cfs'}
# distance3/7157740stations.json
# 07157740WWR_flow.csv
# distance3/7157940stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07157940&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57780', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57780_00060': 'cfs'}
# distance3/7157940stations.json
# 07157940WWR_flow.csv
# distance3/7165750stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07165750&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57787', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57787_00060': 'cfs'}
# distance3/7165750stations.json
# 0716575013K_flow.csv
# distance3/7166500stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07166500&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57796', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57796_00060': 'cfs'}
# distance3/7166500stations.json
# 07166500KCNU_flow.csv
# distance3/7167500stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07167500&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57805', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57805_00060': 'cfs'}
# distance3/7167500stations.json
# 0716750013K_flow.csv
# distance3/7169500stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07169500&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57812', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57812_00060': 'cfs'}
# distance3/7169500stations.json
# 07169500KPPF_flow.csv
# distance3/7169800stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07169800&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57820', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57820_00060': 'cfs'}
# distance3/7169800stations.json
# 07169800IDP_flow.csv
# distance3/7170060stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07170060&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['212909', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'212909_00060': 'cfs'}
# exception
# '212909_00060'
# exceptions10.json
# distance3/7170500stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07170500&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57828', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57828_00060': 'cfs'}
# distance3/7170500stations.json
# 07170500KIDP_flow.csv
# distance3/7170700stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07170700&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['212910', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# ['57836', '00065', 'Gage', 'height,', 'feet']
# []
# {'212910_00060': 'cfs', '57836_00065': 'height'}
# exception
# '212910_00060'
# exceptions10.json
# distance3/7170990stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07170990&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57844', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57844_00060': 'cfs'}
# distance3/7170990stations.json
# 07170990CFV_flow.csv
# distance3/7171600stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07171600&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['212911', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'212911_00060': 'cfs'}
# exception
# '212911_00060'
# exceptions10.json
# distance3/7172000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07172000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57850', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57850_00060': 'cfs'}
# distance3/7172000stations.json
# 07172000KBVO_flow.csv
# distance3/7173300stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07173300&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['212912', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'212912_00060': 'cfs'}
# exception
# '212912_00060'
# exceptions10.json
# distance3/7179300stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07179300&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57858', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57858_00060': 'cfs'}
# distance3/7179300stations.json
# 07179300KFRI_flow.csv
# distance3/7179500stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07179500&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57864', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57864_00060': 'cfs'}
# distance3/7179500stations.json
# 07179500KEMP_flow.csv
# distance3/7179700stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07179700&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57873', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57873_00060': 'cfs'}
# distance3/7179700stations.json
# 07179700KEMP_flow.csv
# distance3/7179710stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07179710&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7179730stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07179730&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57886', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57886_00060': 'cfs'}
# distance3/7179730stations.json
# 07179730EMP_flow.csv
# distance3/7179750stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07179750&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57895', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57895_00060': 'cfs'}
# distance3/7179750stations.json
# 07179750EMP_flow.csv
# distance3/7179785stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07179785&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['165894', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'165894_00060': 'cfs'}
# distance3/7179785stations.json
# 07179785SLN_flow.csv
# distance3/7179795stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07179795&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57910', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57910_00060': 'cfs'}
# distance3/7179795stations.json
# 07179795KEWK_flow.csv
# distance3/7180200stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07180200&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7180400stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07180400&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57938', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57938_00060': 'cfs'}
# distance3/7180400stations.json
# 07180400KEWK_flow.csv
# distance3/7180500stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07180500&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57940', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57940_00060': 'cfs'}
# distance3/7180500stations.json
# 07180500KEWK_flow.csv
# distance3/7182000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07182000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['253851', '00065', 'Gage', 'height,', 'feet']
# ['259108', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'253851_00065': 'height', '259108_00060': 'cfs'}
# exception
# '253851_00065'
# exceptions10.json
# distance3/7182200stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07182200&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57948', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57948_00060': 'cfs'}
# distance3/7182200stations.json
# 07182200KEMP_flow.csv
# distance3/7182250stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07182250&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57954', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57954_00060': 'cfs'}
# distance3/7182250stations.json
# 07182250KEMP_flow.csv
# distance3/7182260stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07182260&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57969', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57969_00060': 'cfs'}
# distance3/7182260stations.json
# 07182260EMP_flow.csv
# distance3/7182280stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07182280&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['212913', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'212913_00060': 'cfs'}
# exception
# '212913_00060'
# exceptions10.json
# distance3/7182390stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07182390&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['251198', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'251198_00060': 'cfs'}
# distance3/7182390stations.json
# 07182390EMP_flow.csv
# distance3/7182510stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07182510&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['57993', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'57993_00060': 'cfs'}
# distance3/7182510stations.json
# 07182510EMP_flow.csv
# distance3/7183000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07183000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['58007', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'58007_00060': 'cfs'}
# distance3/7183000stations.json
# 07183000K88_flow.csv
# distance3/7183300stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07183300&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7183500stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07183500&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['58029', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'58029_00060': 'cfs'}
# distance3/7183500stations.json
# 07183500KPPF_flow.csv
# distance3/7184000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07184000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['58044', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'58044_00060': 'cfs'}
# distance3/7184000stations.json
# 07184000KPTS_flow.csv
# distance3/7184500stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07184500&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['58050', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'58050_00060': 'cfs'}
# distance3/7184500stations.json
# 07184500KPPF_flow.csv
# distance3/7185700stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07185700&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['77850', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'77850_00060': 'cfs'}
# distance3/7185700stations.json
# 07185700HFJ_flow.csv
# distance3/7185765stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07185765&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['77853', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'77853_00060': 'cfs'}
# distance3/7185765stations.json
# 07185765JLN_flow.csv
# distance3/7185910stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07185910&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['77859', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'77859_00060': 'cfs'}
# distance3/7185910stations.json
# 07185910JLN_flow.csv
# distance3/7186000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07186000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['77863', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'77863_00060': 'cfs'}
# distance3/7186000stations.json
# 07186000JLN_flow.csv
# distance3/7186055stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07186055&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['58058', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'58058_00060': 'cfs'}
# distance3/7186055stations.json
# 07186055PTS_flow.csv
# distance3/7186475stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07186475&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['221786', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'221786_00060': 'cfs'}
# exception
# '221786_00060'
# exceptions10.json
# distance3/7186690stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07186690&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['221787', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'221787_00060': 'cfs'}
# exception
# '221787_00060'
# exceptions10.json
# distance3/7186900stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07186900&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['77871', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'77871_00060': 'cfs'}
# distance3/7186900stations.json
# 07186900KHFJ_flow.csv
# distance3/7187000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07187000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['77876', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'77876_00060': 'cfs'}
# distance3/7187000stations.json
# 07187000KJLN_flow.csv
# distance3/7187600stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07187600&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['58064', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'58064_00060': 'cfs'}
# distance3/7187600stations.json
# 07187600KJLN_flow.csv
# distance3/7188653stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07188653&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['77883', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'77883_00060': 'cfs'}
# distance3/7188653stations.json
# 07188653ROG_flow.csv
# distance3/7188838stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07188838&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['77886', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'77886_00060': 'cfs'}
# distance3/7188838stations.json
# 07188838KVBT_flow.csv
# distance3/7188885stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07188885&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['77892', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'77892_00060': 'cfs'}
# distance3/7188885stations.json
# 07188885KGMJ_flow.csv
# distance3/7189000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07189000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['112237', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'112237_00060': 'cfs'}
# distance3/7189000stations.json
# 07189000GMJ_flow.csv
# distance3/7189100stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07189100&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['77896', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'77896_00060': 'cfs'}
# distance3/7189100stations.json
# 07189100GMJ_flow.csv
# distance3/7268000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07268000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80068', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80068_00060': 'cfs'}
# distance3/7268000stations.json
# 07268000KUOX_flow.csv
# distance3/7273100stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07273100&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['227349', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'227349_00060': 'cfs'}
# distance3/7273100stations.json
# 07273100PMU_flow.csv
# distance3/7274000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07274000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80080', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80080_00060': 'cfs'}
# distance3/7274000stations.json
# 07274000UOX_flow.csv
# distance3/7274251stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07274251&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['221827', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'221827_00060': 'cfs'}
# exception
# '221827_00060'
# exceptions10.json
# distance3/7274252stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07274252&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['226590', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'226590_00060': 'cfs'}
# distance3/7274252stations.json
# 07274252UOX_flow.csv
# distance3/7275530stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07275530&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['221828', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'221828_00060': 'cfs'}
# exception
# '221828_00060'
# exceptions10.json
# distance3/7275900stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07275900&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80088', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80088_00060': 'cfs'}
# distance3/7275900stations.json
# 07275900KOLV_flow.csv
# distance3/7277700stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07277700&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['221829', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'221829_00060': 'cfs'}
# exception
# '221829_00060'
# exceptions10.json
# distance3/7277730stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07277730&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['221830', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'221830_00060': 'cfs'}
# exception
# '221830_00060'
# exceptions10.json
# distance3/7280010stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07280010&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7280340stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07280340&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['221831', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'221831_00060': 'cfs'}
# exception
# '221831_00060'
# exceptions10.json
# distance3/7280400stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07280400&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['221832', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'221832_00060': 'cfs'}
# exception
# '221832_00060'
# exceptions10.json
# distance3/7280460stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07280460&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['221833', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'221833_00060': 'cfs'}
# exception
# '221833_00060'
# exceptions10.json
# distance3/7281600stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07281600&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80096', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80096_00060': 'cfs'}
# distance3/7281600stations.json
# 07281600KGWO_flow.csv
# distance3/7281960stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07281960&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['221834', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'221834_00060': 'cfs'}
# exception
# '221834_00060'
# exceptions10.json
# distance3/7281977stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07281977&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['221835', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'221835_00060': 'cfs'}
# exception
# '221835_00060'
# exceptions10.json
# distance3/7282000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07282000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80102', '00065', 'Gage', 'height,', 'feet']
# ['80103', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second,', 'FINAL', 'UNCOMBINED']
# []
# {'80102_00065': 'height', '80103_00060': 'cfs'}
# exception
# '80102_00065'
# exceptions10.json
# distance3/7282075stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07282075&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['205530', '00065', 'Gage', 'height,', 'feet,', 'RADAR']
# ['205540', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second,', '[(2)]']
# ['221836', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'205530_00065': 'height', '205540_00060': 'cfs', '221836_00060': 'cfs'}
# exception
# '205530_00065'
# exceptions10.json
# distance3/7282090stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07282090&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['221837', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'221837_00060': 'cfs'}
# exception
# '221837_00060'
# exceptions10.json
# distance3/7282097stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07282097&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['221838', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'221838_00060': 'cfs'}
# exception
# '221838_00060'
# exceptions10.json
# distance3/7282100stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07282100&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7283000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07283000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80109', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80109_00060': 'cfs'}
# distance3/7283000stations.json
# 07283000UOX_flow.csv
# distance3/7285500stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07285500&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80122', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80122_00060': 'cfs'}
# distance3/7285500stations.json
# 072855005A6_flow.csv
# distance3/7285510stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07285510&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['221839', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'221839_00060': 'cfs'}
# exception
# '221839_00060'
# exceptions10.json
# distance3/7287150stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07287150&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['221840', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'221840_00060': 'cfs'}
# exception
# '221840_00060'
# exceptions10.json
# distance3/7287160stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07287160&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['225283', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'225283_00060': 'cfs'}
# distance3/7287160stations.json
# 07287160GWO_flow.csv
# distance3/7287355stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07287355&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['221841', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'221841_00060': 'cfs'}
# exception
# '221841_00060'
# exceptions10.json
# distance3/7287400stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07287400&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['221842', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'221842_00060': 'cfs'}
# exception
# '221842_00060'
# exceptions10.json
# distance3/7287404stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07287404&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['226391', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'226391_00060': 'cfs'}
# distance3/7287404stations.json
# 07287404GWO_flow.csv
# distance3/7287700stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07287700&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7288000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07288000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7288048stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07288048&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7288068stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07288068&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80146', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80146_00060': 'cfs'}
# distance3/7288068stations.json
# 07288068KRNV_flow.csv
# distance3/7288280stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07288280&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80154', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80154_00060': 'cfs'}
# distance3/7288280stations.json
# 07288280KRNV_flow.csv
# distance3/7288500stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07288500&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80160', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80160_00060': 'cfs'}
# distance3/7288500stations.json
# 07288500RNV_flow.csv
# distance3/7288521stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07288521&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80169', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80169_00060': 'cfs'}
# distance3/7288521stations.json
# 07288521RNV_flow.csv
# distance3/7288580stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07288580&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7288650stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07288650&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80175', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80175_00060': 'cfs'}
# distance3/7288650stations.json
# 07288650KGLH_flow.csv
# distance3/7288700stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07288700&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/728875070stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=728875070&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7288800stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07288800&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7288847stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07288847&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7288860stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07288860&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80218', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80218_00060': 'cfs'}
# distance3/7288860stations.json
# 07288860KGLH_flow.csv
# distance3/7288939stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07288939&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7288955stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07288955&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['221844', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# ['80241', '00065', 'Gage', 'height,', 'feet']
# []
# {'221844_00060': 'cfs', '80241_00065': 'height'}
# exception
# '221844_00060'
# exceptions10.json
# distance3/7289000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07289000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80244', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80244_00060': 'cfs'}
# distance3/7289000stations.json
# 07289000VKS_flow.csv
# distance3/7289350stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07289350&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80255', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80255_00060': 'cfs'}
# distance3/7289350stations.json
# 072893505A6_flow.csv
# distance3/7289730stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07289730&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80260', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80260_00060': 'cfs'}
# distance3/7289730stations.json
# 07289730KMBO_flow.csv
# distance3/7290000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07290000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80265', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80265_00060': 'cfs'}
# distance3/7290000stations.json
# 07290000VKS_flow.csv
# distance3/7290650stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07290650&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80271', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80271_00060': 'cfs'}
# distance3/7290650stations.json
# 07290650VKS_flow.csv
# distance3/7290830stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07290830&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['168482', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'168482_00060': 'cfs'}
# distance3/7290830stations.json
# 07290830KHEZ_flow.csv
# distance3/7291000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07291000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80277', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80277_00060': 'cfs'}
# distance3/7291000stations.json
# 07291000KMCB_flow.csv
# distance3/7292500stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07292500&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80281', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80281_00060': 'cfs'}
# distance3/7292500stations.json
# 07292500KHEZ_flow.csv
# distance3/7294550stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07294550&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7294800stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07294800&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7295000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07295000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['80289', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'80289_00060': 'cfs'}
# distance3/7295000stations.json
# 072950000R4_flow.csv
# distance3/7344400stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07344400&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7344425stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07344425&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7344450stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07344450&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7344460stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07344460&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7346450stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07346450&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7348000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07348000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7348098stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07348098&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7348500stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07348500&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7348550stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07348550&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7348555stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07348555&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7348700stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07348700&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['62249', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'62249_00060': 'cfs'}
# distance3/7348700stations.json
# 07348700MNE_flow.csv
# distance3/7349000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07349000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7349298stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07349298&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7349374stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07349374&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7349450stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07349450&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['165920', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'165920_00060': 'cfs'}
# distance3/7349450stations.json
# 07349450MNE_flow.csv
# distance3/7349500stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07349500&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7349650stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07349650&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7349660stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07349660&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7349849stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07349849&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7349860stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07349860&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['62300', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'62300_00060': 'cfs'}
# distance3/7349860stations.json
# 07349860DTN_flow.csv
# distance3/7349890stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07349890&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/7349898stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=07349898&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# ...
# Request finished
# ['209574', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'209574_00060': 'cfs'}
# exception
# '209574_00060'
# exceptions10.json
# distance3/9415900stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09415900&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103640', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103640_00060': 'cfs'}
# distance3/9415900stations.json
# 09415900LSV_flow.csv
# distance3/9415908stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09415908&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103644', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103644_00060': 'cfs'}
# distance3/9415908stations.json
# 09415908LSV_flow.csv
# distance3/9415910stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09415910&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103647', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103647_00060': 'cfs'}
# distance3/9415910stations.json
# 09415910LSV_flow.csv
# distance3/9415920stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09415920&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103649', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103649_00060': 'cfs'}
# distance3/9415920stations.json
# 09415920LSV_flow.csv
# distance3/9415927stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09415927&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103653', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103653_00060': 'cfs'}
# distance3/9415927stations.json
# 09415927LSV_flow.csv
# distance3/9416000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09416000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103655', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103655_00060': 'cfs'}
# distance3/9416000stations.json
# 09416000LSV_flow.csv
# distance3/9417500stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09417500&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103659', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103659_00060': 'cfs'}
# distance3/9417500stations.json
# 09417500CDC_flow.csv
# distance3/9418500stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09418500&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103662', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103662_00060': 'cfs'}
# distance3/9418500stations.json
# 09418500KSGU_flow.csv
# distance3/9418700stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09418700&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['209575', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'209575_00060': 'cfs'}
# exception
# '209575_00060'
# exceptions10.json
# distance3/9419000stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103665', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103665_00060': 'cfs'}
# distance3/9419000stations.json
# 09419000LSV_flow.csv
# distance3/9419507stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419507&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103668', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103668_00060': 'cfs'}
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# distance3/9419507stations.json
# 09419507LSV_flow.csv
# distance3/9419515stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419515&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['209576', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'209576_00060': 'cfs'}
# exception
# '209576_00060'
# exceptions10.json
# distance3/9419530stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419530&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['247144', '00065', 'Gage', 'height,', 'feet']
# ['247145', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'247144_00065': 'height', '247145_00060': 'cfs'}
# exception
# '247144_00065'
# exceptions10.json
# distance3/9419547stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419547&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103671', '00065', 'Gage', 'height,', 'feet']
# ['103672', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103671_00065': 'height', '103672_00060': 'cfs'}
# exception
# '103671_00065'
# exceptions10.json
# distance3/9419625stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419625&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103676', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103676_00060': 'cfs'}
# distance3/9419625stations.json
# 09419625KVGT_flow.csv
# distance3/9419648stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419648&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['209577', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'209577_00060': 'cfs'}
# exception
# '209577_00060'
# exceptions10.json
# distance3/94196497stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=94196497&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/9419649stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419649&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['209578', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'209578_00060': 'cfs'}
# exception
# '209578_00060'
# exceptions10.json
# distance3/94196557stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=94196557&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/9419655stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419655&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['209580', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'209580_00060': 'cfs'}
# exception
# '209580_00060'
# exceptions10.json
# distance3/9419656stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419656&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['209582', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'209582_00060': 'cfs'}
# exception
# '209582_00060'
# exceptions10.json
# distance3/9419658stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419658&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103679', '00065', 'Gage', 'height,', 'feet']
# ['103680', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# ['103681', '00045', 'Precipitation,', 'total,', 'inches']
# []
# {'103679_00065': 'height', '103680_00060': 'cfs', '103681_00045': 'Precipitation'}
# exception
# '103679_00065'
# exceptions10.json
# distance3/9419659stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419659&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103683', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103683_00060': 'cfs'}
# distance3/9419659stations.json
# 09419659LSV_flow.csv
# distance3/9419665stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419665&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103687', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103687_00060': 'cfs'}
# distance3/9419665stations.json
# 09419665LSV_flow.csv
# distance3/9419672stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419672&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['209583', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'209583_00060': 'cfs'}
# exception
# '209583_00060'
# exceptions10.json
# distance3/9419673stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419673&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['209584', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'209584_00060': 'cfs'}
# exception
# '209584_00060'
# exceptions10.json
# distance3/9419674stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419674&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['209585', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'209585_00060': 'cfs'}
# exception
# '209585_00060'
# exceptions10.json
# distance3/9419676stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419676&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['209586', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'209586_00060': 'cfs'}
# exception
# '209586_00060'
# exceptions10.json
# distance3/94196775stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=94196775&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/94196781stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=94196781&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/94196783stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=94196783&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/94196784stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=94196784&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# {}
# exception
# 'tz_cd'
# exceptions10.json
# distance3/9419679stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419679&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103702', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103702_00060': 'cfs'}
# distance3/9419679stations.json
# 09419679LAS_flow.csv
# distance3/9419688stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419688&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['209588', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'209588_00060': 'cfs'}
# exception
# '209588_00060'
# exceptions10.json
# distance3/9419695stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419695&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['209589', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'209589_00060': 'cfs'}
# exception
# '209589_00060'
# exceptions10.json
# distance3/9419696stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419696&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103705', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103705_00060': 'cfs'}
# distance3/9419696stations.json
# 09419696LAS_flow.csv
# distance3/9419698stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419698&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['163738', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'163738_00060': 'cfs'}
# distance3/9419698stations.json
# 09419698LAS_flow.csv
# distance3/9419700stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419700&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103708', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103708_00060': 'cfs'}
# distance3/9419700stations.json
# 09419700LAS_flow.csv
# distance3/9419740stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419740&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103711', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103711_00060': 'cfs'}
# distance3/9419740stations.json
# 09419740BVU_flow.csv
# distance3/9419745stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419745&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103715', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103715_00060': 'cfs'}
# distance3/9419745stations.json
# 09419745LAS_flow.csv
# distance3/9419747stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419747&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['163744', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'163744_00060': 'cfs'}
# distance3/9419747stations.json
# 09419747LAS_flow.csv
# distance3/9419749stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419749&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['163741', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'163741_00060': 'cfs'}
# distance3/9419749stations.json
# 09419749LSV_flow.csv
# distance3/9419753stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419753&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103718', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103718_00060': 'cfs'}
# distance3/9419753stations.json
# 09419753LSV_flow.csv
# distance3/9419756stations.json
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=09419756&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['103722', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'103722_00060': 'cfs'}

# %%
df.write_csv()
# Out:
#        Unnamed: 0_x              hour_updated  ...  194445_00060_cd     cfs
# 43618       43613.0 2018-12-30 04:00:00+00:00  ...                P  1820.0
# 43619       43614.0 2018-12-30 05:00:00+00:00  ...                P  1800.0
# 43620       43615.0 2018-12-30 06:00:00+00:00  ...                P  1780.0
# 43621       43616.0 2018-12-30 07:00:00+00:00  ...                P  1760.0
# 43622       43617.0 2018-12-30 08:00:00+00:00  ...                P  1730.0
# ...             ...                       ...  ...              ...     ...
# 28824       28821.0 2017-04-20 19:00:00+00:00  ...              NaN     NaN
# 31446       31443.0 2017-08-08 16:00:00+00:00  ...              NaN     NaN
# 32122       32119.0 2017-09-05 20:00:00+00:00  ...              NaN     NaN
# 33571       33568.0 2017-11-05 05:00:00+00:00  ...              NaN     NaN
# 42274       42270.0 2018-11-04 05:00:00+00:00  ...              NaN     NaN
#
# [100 rows x 13 columns]

# %%
def compute_meta_stats(df:pd.DataFrame):
  pass
def compute_elev(meta_data):
  pass

# %%
df.count()
# Out:
# Unnamed: 0      43682
# hour_updated    43682
# p01m            43682
# valid           43682
# tmpf            43682
# dtype: int64

# %%
with open("exceptions.json") as f:
  data = json.load(f)
len(data.keys())
# Out:
# 165

# %%
make_usgs_data(datetime(2014,1,1), datetime(2019,1,1), "06894000")
# Out:
# Getting request from USGS
# https://nwis.waterdata.usgs.gov/usa/nwis/uv/?cb_00060=on&cb_00065&format=rdb&site_no=06894000&period=&begin_date=2014-01-01&end_date=2019-01-01
# Request finished
# ['76992', '00060', 'Discharge,', 'cubic', 'feet', 'per', 'second']
# []
# {'76992_00060': 'cfs'}
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2828: DtypeWarning: Columns (2,5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
#         Unnamed: 0 agency_cd   site_no  ... 76992_00060 76992_00060_cd   cfs
# 0                0        5s       15s  ...         14n            10s   14n
# 1                1      USGS  06894000  ...        27.8              A  27.8
# 2                2      USGS  06894000  ...        27.8              A  27.8
# 3                3      USGS  06894000  ...        27.8              A  27.8
# 4                4      USGS  06894000  ...        27.8              A  27.8
# ...            ...       ...       ...  ...         ...            ...   ...
# 171642      171642      USGS   6894000  ...         391              A   391
# 171643      171643      USGS   6894000  ...         391              A   391
# 171644      171644      USGS   6894000  ...         387              A   387
# 171645      171645      USGS   6894000  ...         387              A   387
# 171646      171646      USGS   6894000  ...         387              A   387
#
# [171647 rows x 8 columns]

# %%
min_flow
# Out:
# 21.1

# %%
ol_timezone = pytz.timezone(timezone_map[df['tz_cd'].iloc[1]])
new_timezone = pytz.timezone("UTC")
ol_timezone.localize(datetime.strptime(df['datetime'].iloc[1], "%Y-%m-%d %H:%M")).astimezone(new_timezone)
# Out:
# datetime.datetime(2014, 4, 1, 6, 0, tzinfo=<UTC>)

# %%
df.head()
# Out:
#    Unnamed: 0 agency_cd   site_no  ... 82505_00060 82505_00060_cd  cfs
# 0           0        5s       15s  ...         14n            10s  14n
# 1           1      USGS  06127500  ...         200              A  200
# 2           2      USGS  06127500  ...         200              A  200
# 3           3      USGS  06127500  ...         200              A  200
# 4           4      USGS  06127500  ...         200              A  200
#
# [5 rows x 8 columns]

# %%
df = pd.read_csv("06127500_flow_data.csv")
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         Unnamed: 0 agency_cd   site_no  ... 82505_00060 82505_00060_cd  cfs
# 0                0        5s       15s  ...         14n            10s  14n
# 1                1      USGS  06127500  ...         200              A  200
# 2                2      USGS  06127500  ...         200              A  200
# 3                3      USGS  06127500  ...         200              A  200
# 4                4      USGS  06127500  ...         200              A  200
# ...            ...       ...       ...  ...         ...            ...  ...
# 104733      104733      USGS   6127500  ...         262              A  262
# 104734      104734      USGS   6127500  ...         265              P  265
# 104735      104735      USGS   6127500  ...         268              P  268
# 104736      104736      USGS   6127500  ...         265              P  265
# 104737      104737      USGS   6127500  ...         Ssn              P  Ssn
#
# [104738 rows x 8 columns]

# %%
data[data.datetime.dt.minute==0]
# Out:
#         Unnamed: 0 agency_cd   site_no  ... 194445_00060 194445_00060_cd     cfs
# 1                1      USGS  01388500  ...          606               A   606.0
# 5                5      USGS  01388500  ...          601               A   601.0
# 9                9      USGS  01388500  ...          590               A   590.0
# 13              13      USGS  01388500  ...          584               A   584.0
# 17              17      USGS  01388500  ...          579               A   579.0
# ...            ...       ...       ...  ...          ...             ...     ...
# 175259      175259      USGS   1388500  ...         2650               P  2650.0
# 175263      175263      USGS   1388500  ...         2620               P  2620.0
# 175267      175267      USGS   1388500  ...         2600               P  2600.0
# 175271      175271      USGS   1388500  ...         2570               P  2570.0
# 175275      175275      USGS   1388500  ...         2550               P  2550.0
#
# [43820 rows x 8 columns]

# %%
pre[pre['hour_updated'] == datetime()
# Out:
#        Unnamed: 0              hour_updated  p01m             valid       tmpf
# 0               0 2014-01-01 01:00:00+00:00   0.0  2014-01-01 00:53  28.040000
# 1               1 2014-01-01 02:00:00+00:00   0.0  2014-01-01 01:53  26.960000
# 2               2 2014-01-01 03:00:00+00:00   0.0  2014-01-01 02:53  26.060000
# 3               3 2014-01-01 04:00:00+00:00   0.0  2014-01-01 03:53  24.080000
# 4               4 2014-01-01 05:00:00+00:00   0.0  2014-01-01 04:53  24.080000
# ...           ...                       ...   ...               ...        ...
# 43677       43677 2019-01-01 20:00:00+00:00   0.0  2019-01-01 19:05  49.100000
# 43678       43678 2019-01-01 21:00:00+00:00   0.0  2019-01-01 20:05  47.038462
# 43679       43679 2019-01-01 22:00:00+00:00   0.0  2019-01-01 21:05  45.315385
# 43680       43680 2019-01-01 23:00:00+00:00   0.0  2019-01-01 22:05  44.361538
# 43681       43681 2019-01-02 00:00:00+00:00   0.0  2019-01-01 23:05  43.500000
#
# [43682 rows x 5 columns]

# %%
df.to_csv("example_csv.csv")

# %%
# !gsutil cp example_csv.csv gs://predict_cfs/combined_data/example_csv.csv
# Out:
# Copying file://example_csv.csv [Content-Type=text/csv]...
# / [1 files][  5.7 MiB/  5.7 MiB]
# Operation completed over 1 objects/5.7 MiB.

# %%
count_nan = len(df) - df.count()

# %%
count_nan
# Out:
# Unnamed: 0_x       163
# hour_updated       163
# p01m               163
# valid              163
# tmpf               163
# Unnamed: 0_y        31
# agency_cd           31
# site_no             31
# datetime            31
# tz_cd               31
# 194445_00060        31
# 194445_00060_cd     31
# cfs                 31
# dtype: int64

# %%
count_nan_precip = len(pre) - pre.count()
count_nan_precip
# Out:
# Unnamed: 0      0
# hour_updated    0
# p01m            0
# valid           0
# tmpf            0
# dtype: int64

# %%
len(pre)
# Out:
# 43682

# %%
df
# Out:
#         Unnamed: 0 agency_cd   site_no  ... 194445_00060 194445_00060_cd     cfs
# 1                1      USGS  01388500  ...          606               A   606.0
# 5                5      USGS  01388500  ...          601               A   601.0
# 9                9      USGS  01388500  ...          590               A   590.0
# 13              13      USGS  01388500  ...          584               A   584.0
# 17              17      USGS  01388500  ...          579               A   579.0
# ...            ...       ...       ...  ...          ...             ...     ...
# 175259      175259      USGS   1388500  ...         2650               P  2650.0
# 175263      175263      USGS   1388500  ...         2620               P  2620.0
# 175267      175267      USGS   1388500  ...         2600               P  2600.0
# 175271      175271      USGS   1388500  ...         2570               P  2570.0
# 175275      175275      USGS   1388500  ...         2550               P  2550.0
#
# [43820 rows x 8 columns]

# %%
joined_df['p01m']=joined_df.fillna(method='ffill').fillna(method='bfill')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2f6ae08252c3> in <module>()
# ----> 1 joined_df['p01m']=joined_df.fillna(method='ffill').fillna(method='bfill')
#
# NameError: name 'joined_df' is not defined

# %%
joined_df[joined_df['p01m'].isna()].sort_values(by='datetime')
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0_x, hour_updated, p01m, valid, tmpf, Unnamed: 0_y, agency_cd, site_no, datetime, tz_cd, 194445_00060, 194445_00060_cd, cfs]
# Index: []

# %%
joined_d['p01m']=(df['p01m'].fillna(method='ffill') + df['p01m'].fillna(method='bfill'))/2

# %%
joined_df.set_index('datetime').sort_index().tail(40)
# Out:
#                            Unnamed: 0_x  ...     cfs
# datetime                                 ...
# 2019-01-01 16:00:00+00:00       43673.0  ...  2690.0
# 2019-01-01 17:00:00+00:00       43674.0  ...  2670.0
# 2019-01-01 18:00:00+00:00       43675.0  ...  2650.0
# 2019-01-01 19:00:00+00:00       43676.0  ...  2650.0
# 2019-01-01 20:00:00+00:00       43677.0  ...  2650.0
# 2019-01-01 21:00:00+00:00       43678.0  ...  2650.0
# 2019-01-01 22:00:00+00:00       43679.0  ...  2650.0
# 2019-01-01 23:00:00+00:00       43680.0  ...  2650.0
# 2019-01-02 00:00:00+00:00       43681.0  ...  2650.0
# NaT                              5746.0  ...     NaN
# NaT                              5747.0  ...     NaN
# NaT                              5748.0  ...     NaN
# NaT                              5749.0  ...     NaN
# NaT                              5750.0  ...     NaN
# NaT                              5751.0  ...     NaN
# NaT                              5752.0  ...     NaN
# NaT                              5753.0  ...     NaN
# NaT                              5754.0  ...     NaN
# NaT                              5755.0  ...     NaN
# NaT                              5756.0  ...     NaN
# NaT                              5757.0  ...     NaN
# NaT                              5758.0  ...     NaN
# NaT                              5759.0  ...     NaN
# NaT                              5760.0  ...     NaN
# NaT                              5761.0  ...     NaN
# NaT                              5762.0  ...     NaN
# NaT                              5763.0  ...     NaN
# NaT                              5764.0  ...     NaN
# NaT                              5765.0  ...     NaN
# NaT                              5766.0  ...     NaN
# NaT                              5767.0  ...     NaN
# NaT                              5768.0  ...     NaN
# NaT                              5769.0  ...     NaN
# NaT                             16935.0  ...     NaN
# NaT                             24858.0  ...     NaN
# NaT                             28821.0  ...     NaN
# NaT                             31443.0  ...     NaN
# NaT                             32119.0  ...     NaN
# NaT                             33568.0  ...     NaN
# NaT                             42270.0  ...     NaN
#
# [40 rows x 12 columns]

# %%
with open("distance3/384456119222101stations.json") as f: 
  data = json.load(f)

# %%
data
# Out:
# {'gage_id': 384456119222101,
#  'stations': [{'cat': 'ASOS',
#    'dist': 42.718108597553965,
#    'missing_precip': 0,
#    'missing_temp': 1184,
#    'station_id': 'MEV'},
#   {'cat': 'ASOS',
#    'dist': 44.719722632504485,
#    'missing_precip': 0,
#    'missing_temp': 380,
#    'station_id': 'BAN'},
#   {'cat': 'ASOS',
#    'dist': 45.53881794914841,
#    'missing_precip': 0,
#    'missing_temp': 380,
#    'station_id': 'KBAN'},
#   {'cat': 'ASOS',
#    'dist': 56.31511546856264,
#    'missing_precip': 262506,
#    'missing_temp': 274514,
#    'station_id': 'TVL'},
#   {'cat': 'ASOS',
#    'dist': 56.403195751932756,
#    'missing_precip': 262506,
#    'missing_temp': 274514,
#    'station_id': 'KTVL'},
#   {'cat': 'ASOS',
#    'dist': 57.45852353307815,
#    'missing_precip': 0,
#    'missing_temp': 46,
#    'station_id': 'KCXP'},
#   {'cat': 'ASOS',
#    'dist': 58.310412686357125,
#    'missing_precip': 0,
#    'missing_temp': 46,
#    'station_id': 'CXP'},
#   {'cat': 'ASOS',
#    'dist': 68.23565331011748,
#    'missing_precip': 0,
#    'missing_temp': 65,
#    'station_id': 'HTH'}]}

# %%
# !ls
# Out:
# 01010000data.tsv	0384456119222101data.tsv
# 01010000_flow_data.csv	0384456119222101.txt
# 01010000.txt		10100001010000stations.json_flow.csv
# 01010070data.tsv	10100701010070stations.json_flow.csv
# 01010070_flow_data.csv	13885001388500stations.json_flow.csv
# 01010070.txt		adc.json
# 01388500data.tsv	asos
# 01388500_flow_data.csv	distance3
# 01388500.txt		sample_data

# %%
inspect_df = pd.read_csv("10100001010000stations.json_flow.csv").sort_values('datetime')

# %%
sum(pd.isnull(inspect_df['p01m']))
# Out:
# 729

# %%
len(inspect_df)
# Out:
# 39105

# %%
# Total of 43,800
inspect_df2 = pd.read_csv("10100701010070stations.json_flow.csv").sort_values('datetime')

# %%
len(inspect_df2)
# Out:
# 39054

# %%
sum(pd.isnull(inspect_df2['p01m']))
# Out:
# 678

# %%
sum(pd.isnull(inspect_df2['cfs']))
# Out:
# 13627

# %%
# !ls asos
# Out:
# 04W.csv   CWNL.csv  HZR.csv   KCXY.csv	KLCI.csv  KSPW.csv  OLG.csv
# 05U.csv   CWOE.csv  HZX.csv   KCYS.csv	KLDJ.csv  KSRB.csv  OLU.csv
# 0R0.csv   CWPE.csv  I16.csv   KD25.csv	KLDM.csv  KSTC.csv  OLV.csv
# 0R4.csv   CWQH.csv  I35.csv   KD39.csv	KLEB.csv  KSTF.csv  OMA.csv
# 12N.csv   CWQO.csv  I63.csv   KD50.csv	KLEW.csv  KSTJ.csv  ONA.csv
# 13K.csv   CWRT.csv  I67.csv   KD55.csv	KLEX.csv  KSTK.csv  ONL.csv
# 14Y.csv   CWRY.csv  I69.csv   KD60.csv	KLFT.csv  KSTL.csv  ONZ.csv
# 19S.csv   CWSS.csv  IAB.csv   KD95.csv	KLGA.csv  KSTP.csv  OOSA.csv
# 1A6.csv   CWST.csv  IAD.csv   KDAA.csv	KLHX.csv  KSUS.csv  OPL.csv
# 1GM.csv   CWSW.csv  IBM.csv   KDAW.csv	KLJF.csv  KSUW.csv  ORB.csv
# 1K1.csv   CWTN.csv  ICR.csv   KDCA.csv	KLLJ.csv  KSUX.csv  ORE.csv
# 1KM.csv   CWTT.csv  ICT.csv   KDDC.csv	KLLQ.csv  KSWO.csv  ORH.csv
# 1LM.csv   CWVN.csv  IDP.csv   KDDH.csv	KLNK.csv  KSYF.csv  OSC.csv
# 1M4.csv   CWVP.csv  IEN.csv   KDEH.csv	KLNL.csv  KSYN.csv  OTG.csv
# 1M5.csv   CWVU.csv  IER.csv   KDET.csv	KLNP.csv  KSZT.csv  OTM.csv
# 1P1.csv   CWWF.csv  IFP.csv   KDFI.csv	KLNS.csv  KTAN.csv  OVL.csv
# 1V4.csv   CWXL.csv  IGM.csv   KDLH.csv	KLOL.csv  KTCL.csv  OVS.csv
# 20U.csv   CXBK.csv  IJD.csv   KDLN.csv	KLOM.csv  KTDZ.csv  OWA.csv
# 21D.csv   CXBO.csv  IJX.csv   KDMH.csv	KLOU.csv  KTEB.csv  OWB.csv
# 2C8.csv   CXBR.csv  IKW.csv   KDMO.csv	KLOZ.csv  KTEW.csv  OWD.csv
# 2G4.csv   CXDB.csv  ILG.csv   KDMW.csv	KLRJ.csv  KTHV.csv  OWI.csv
# 2G9.csv   CXFM.csv  ILN.csv   KDNS.csv	KLSE.csv  KTIF.csv  OWP.csv
# 2I0.csv   CXHA.csv  IML.csv   KDRA.csv	KLUK.csv  KTKC.csv  OXB.csv
# 2P2.csv   CXP.csv   IMS.csv   KDRI.csv	KLUM.csv  KTOB.csv  OXC.csv
# 2V5.csv   CXWM.csv  IMT.csv   KDRM.csv	KLVM.csv  KTOL.csv  OXD.csv
# 2V6.csv   CXWN.csv  INL.csv   KDSM.csv	KLVN.csv  KTOP.csv  OXI.csv
# 2W6.csv   CXY.csv   INS.csv   KDTL.csv	KLWA.csv  KTOR.csv  OZS.csv
# 2WX.csv   CYAM.csv  IOB.csv   KDTN.csv	KLWC.csv  KTPH.csv  OZW.csv
# 3AU.csv   CYCK.csv  IRK.csv   KDTW.csv	KLWD.csv  KTQE.csv  P28.csv
# 3D2.csv   CYCX.csv  IRS.csv   KDUH.csv	KLWM.csv  KTRI.csv  P53.csv
# 3F3.csv   CYEN.csv  ISN.csv   KDVK.csv	KLWT.csv  KTRK.csv  P58.csv
# 3K3.csv   CYFC.csv  ISQ.csv   KDVP.csv	KLXL.csv  KTTF.csv  P59.csv
# 3L4.csv   CYQB.csv  ITRA.csv  KDXX.csv	KLXN.csv  KTTN.csv  P60.csv
# 3LF.csv   CYQG.csv  ITR.csv   KDYA.csv	KLXT.csv  KTUL.csv  P68.csv
# 3N8.csv   CYQK.csv  IWD.csv   KDYL.csv	KLYV.csv  KTUP.csv  PAH.csv
# 3R7.csv   CYQL.csv  IWI.csv   KDYR.csv	KM25.csv  KTVC.csv  PBX.csv
# 40B.csv   CYQT.csv  IXD.csv   KDYT.csv	KM30.csv  KTVF.csv  PCD.csv
# 4M9.csv   CYSC.csv  IYA.csv   KEAR.csv	KM40.csv  KTVK.csv  PDC.csv
# 4R5.csv   CYS.csv   IZG.csv   KEAU.csv	KMBL.csv  KTVL.csv  PEX.csv
# 5A6.csv   CYSJ.csv  JAN.csv   KECS.csv	KMBO.csv  KTVR.csv  PHL.csv
# 5M9.csv   CYWG.csv  JAU.csv   KEED.csv	KMBS.csv  KTWF.csv  PHN.csv
# 5R8.csv   CYXC.csv  JBR.csv   KEEN.csv	KMCB.csv  KTWM.csv  PHT.csv
# 65S.csv   CYXH.csv  JDN.csv   KEFK.csv	KMCD.csv  KTXK.csv  PIB.csv
# 6B0.csv   CYYN.csv  JEF.csv   KEGV.csv	KMCI.csv  KUCY.csv  PKD.csv
# 6I2.csv   CYZR.csv  JER.csv   KEHA.csv	KMCK.csv  KUIN.csv  PLN.csv
# 6L4.csv   CZMJ.csv  JFK.csv   KEHR.csv	KMCW.csv  KUKT.csv  PMH.csv
# 6S0.csv   CZPC.csv  JFZ.csv   KEIR.csv	KMDH.csv  KULM.csv  PMU.csv
# 7N0.csv   CZTB.csv  JHN.csv   KEKN.csv	KMDJ.csv  KUNI.csv  PMV.csv
# 82V.csv   D25.csv   JKJ.csv   KEKO.csv	KMDT.csv  KUNO.csv  PNC.csv
# 8A3.csv   D39.csv   JKL.csv   KEKQ.csv	KMEI.csv  KUOX.csv  PNE.csv
# 8B0.csv   D50.csv   JLN.csv   KELD.csv	KMEM.csv  KUTA.csv  PNM.csv
# 8D3.csv   D55.csv   JMR.csv   KELO.csv	KMGC.csv  KUUU.csv  POE.csv
# 8W2.csv   D60.csv   JRB.csv   KELY.csv	KMGG.csv  KUXL.csv  POF.csv
# 96D.csv   D95.csv   JST.csv   KEMP.csv	KMGJ.csv  KVAY.csv  POU.csv
# 9MN.csv   DAA.csv   JVW.csv   KENL.csv	KMGN.csv  KVBT.csv  POY.csv
# 9V9.csv   DAW.csv   JWN.csv   KEOK.csv	KMGW.csv  KVER.csv  PPF.csv
# AAO.csv   DCA.csv   JXN.csv   KERY.csv	KMGY.csv  KVGT.csv  PPO.csv
# AAS.csv   DDC.csv   JYG.csv   KESC.csv	KMHE.csv  KVIH.csv  PPQ.csv
# AAT.csv   DDH.csv   JYM.csv   KESN.csv	KMHK.csv  KVJI.csv  PQI.csv
# ABE.csv   DET.csv   JYO.csv   KEST.csv	KMHT.csv  KVLL.csv  PQL.csv
# ACB.csv   DFI.csv   JYR.csv   KETH.csv	KMIC.csv  KVPZ.csv  PQN.csv
# ACK.csv   DLH.csv   K04W.csv  KEVV.csv	KMIS.csv  KVSF.csv  PSF.csv
# ACP.csv   DLN.csv   K05U.csv  KEWB.csv	KMJQ.csv  KVTN.csv  PSM.csv
# ACQ.csv   DMH.csv   K12N.csv  KEWK.csv	KMJX.csv  KVVV.csv  PTK.csv
# ACY.csv   DMO.csv   K14Y.csv  KEWR.csv	KMKC.csv  KVWU.csv  PTN.csv
# ADC.csv   DMW.csv   K1A6.csv  KFAM.csv	KMKG.csv  KW22.csv  PTS.csv
# ADG.csv   DOV.csv   K1M4.csv  KFAR.csv	KMKL.csv  KW29.csv  PTT.csv
# ADW.csv   DRA.csv   K1P1.csv  KFCM.csv	KMKT.csv  KW43.csv  PVC.csv
# AEL.csv   DRI.csv   K1V4.csv  KFDK.csv	KMLE.csv  KW99.csv  PVD.csv
# AEX.csv   DRM.csv   K20U.csv  KFET.csv	KMLF.csv  KWAL.csv  PWC.csv
# AFK.csv   DTL.csv   K21D.csv  KFFL.csv	KMLP.csv  KWLD.csv  PWM.csv
# AFN.csv   DTN.csv   K2C8.csv  KFFM.csv	KMLS.csv  KWMC.csv  PYM.csv
# AGC.csv   DTW.csv   K2G4.csv  KFFT.csv	KMLT.csv  KWVL.csv  PYX.csv
# AHQ.csv   DUH.csv   K2I0.csv  KFFX.csv	KMLU.csv  KWWR.csv  PZQ.csv
# AIA.csv   DVK.csv   K2V5.csv  KFGN.csv	KMMK.csv  KWYS.csv  RAW.csv
# AIT.csv   DVP.csv   K2W6.csv  KFIT.csv	KMML.csv  KXLL.csv  RCM.csv
# AIZ.csv   DWU.csv   K2WX.csv  KFKA.csv	KMNE.csv  KXNA.csv  RDR.csv
# AKO.csv   DXX.csv   K3LF.csv  KFKS.csv	KMNM.csv  KXPY.csv  record.json
# ALB.csv   DYA.csv   K3R7.csv  KFLP.csv	KMOB.csv  KXSA.csv  REG.csv
# ALN.csv   DYL.csv   K4M9.csv  KFMM.csv	KMOP.csv  KXVG.csv  REO.csv
# AMN.csv   DYR.csv   K5M9.csv  KFNB.csv	KMPO.csv  KY51.csv  RGK.csv
# ANE.csv   DYT.csv   K5R8.csv  KFNT.csv	KMPV.csv  KY63.csv  RHI.csv
# ANJ.csv   EAN.csv   K65S.csv  KFOE.csv	KMPZ.csv  KY70.csv  RKD.csv
# ANQ.csv   EAR.csv   K6B0.csv  KFOZ.csv	KMQB.csv  KY8.csv   RMN.csv
# ANW.csv   EAU.csv   K7N0.csv  KFPK.csv	KMQS.csv  KYIP.csv  RMY.csv
# AOO.csv   ECS.csv   K82V.csv  KFRI.csv	KMRB.csv  KYKN.csv  RNH.csv
# APN.csv   EED.csv   K88.csv   KFRM.csv	KMSL.csv  LAA.csv   RNO.csv
# APS.csv   EEN.csv   K8D3.csv  KFSD.csv	KMSO.csv  LAN.csv   RNP.csv
# AQP.csv   EFK.csv   K96D.csv  KFSE.csv	KMSP.csv  LAS.csv   RNV.csv
# AQV.csv   EGV.csv   K9V9.csv  KFSW.csv	KMSV.csv  LBE.csv   ROG.csv
# AQW.csv   EHA.csv   KAAO.csv  KFTK.csv	KMSY.csv  LBF.csv   ROS.csv
# ARA.csv   EHR.csv   KAAT.csv  KFVE.csv	KMTN.csv  LBL.csv   ROX.csv
# ARB.csv   EIR.csv   KABE.csv  KFWB.csv	KMUT.csv  LBO.csv   RQB.csv
# ARG.csv   EKN.csv   KACB.csv  KFWC.csv	KMVE.csv  LCG.csv   RRT.csv
# ARV.csv   EKO.csv   KACK.csv  KFWN.csv	KMVL.csv  LCH.csv   RSL.csv
# ASD.csv   EKQ.csv   KACP.csv  KFXY.csv	KMVY.csv  LCI.csv   RSN.csv
# ASG.csv   EKS.csv   KACQ.csv  KFYG.csv	KMWA.csv  LDJ.csv   RST.csv
# ASH.csv   EKX.csv   KACY.csv  KFYV.csv	KMWM.csv  LDM.csv   RTS.csv
# ASL.csv   ELD.csv   KADC.csv  KGAF.csv	KMWO.csv  LEB.csv   RUT.csv
# ASW.csv   ELO.csv   KADG.csv  KGAG.csv	KMZH.csv  LEW.csv   RWF.csv
# ASX.csv   ELY.csv   KADW.csv  KGAI.csv	KNAK.csv  LEX.csv   RXE.csv
# ATY.csv   EMP.csv   KAEL.csv  KGAO.csv	KNEW.csv  LFT.csv   RYM.csv
# AUG.csv   END.csv   KAEX.csv  KGBD.csv	KNHK.csv  LGA.csv   RZN.csv
# AUH.csv   ENL.csv   KAFK.csv  KGBG.csv	KNMM.csv  LHX.csv   RZT.csv
# AUM.csv   ENV.csv   KAFN.csv  KGCC.csv	KNQA.csv  LJF.csv   S25.csv
# AVK.csv   EQA.csv   KAGC.csv  KGCK.csv	KNUI.csv  LLQ.csv   S32.csv
# AXN.csv   ERY.csv   KAHQ.csv  KGCM.csv	KNYC.csv  LNK.csv   SAR.csv
# AZC.csv   ESC.csv   KAIA.csv  KGDB.csv	KNYG.csv  LNL.csv   SAW.csv
# AZO.csv   ESF.csv   KAIO.csv  KGDV.csv	KOCQ.csv  LNP.csv   SAZ.csv
# BAC.csv   ESN.csv   KAIT.csv  KGED.csv	KODX.csv  LNS.csv   SBN.csv
# BAF.csv   EST.csv   KAIZ.csv  KGEY.csv	KOEB.csv  LOL.csv   SBY.csv
# BAM.csv   ETH.csv   KAKO.csv  KGFK.csv	KOEO.csv  LOM.csv   SCF.csv
# BAN.csv   EVU.csv   KALB.csv  KGGG.csv	KOFK.csv  LOU.csv   SCH.csv
# BAX.csv   EVV.csv   KAMN.csv  KGGW.csv	KOGA.csv  LOZ.csv   SDF.csv
# BBB.csv   EWB.csv   KANJ.csv  KGHG.csv	KOJC.csv  LRY.csv   SDY.csv
# BBG.csv   EWK.csv   KANQ.csv  KGHW.csv	KOKV.csv  LSE.csv   SET.csv
# BBW.csv   EWR.csv   KANW.csv  KGLD.csv	KOLF.csv  LSV.csv   SFM.csv
# BCK.csv   EZZ.csv   KAOO.csv  KGLH.csv	KOLU.csv  LUK.csv   SFZ.csv
# BDE.csv   FAM.csv   KAPN.csv  KGLR.csv	KOLV.csv  LUL.csv   SGF.csv
# BDH.csv   FAR.csv   KAQP.csv  KGLW.csv	KOMA.csv  LUM.csv   SGS.csv
# BDL.csv   FCM.csv   KAQV.csv  KGLY.csv	KONA.csv  LVM.csv   SGT.csv
# BEC.csv   FDK.csv   KAQW.csv  KGMJ.csv	KONL.csv  LVN.csv   SGU.csv
# BED.csv   FET.csv   KARA.csv  KGNA.csv	KONZ.csv  LWA.csv   SHR.csv
# BEH.csv   FEW.csv   KARB.csv  KGNR.csv	KOOA.csv  LWC.csv   SHV.csv
# BFF.csv   FFM.csv   KARG.csv  KGOV.csv	KOPL.csv  LWD.csv   SIK.csv
# BFM.csv   FFT.csv   KARV.csv  KGPH.csv	KOQT.csv  LWM.csv   SJS.csv
# BFW.csv   FFX.csv   KASD.csv  KGPI.csv	KORB.csv  LWT.csv   SJX.csv
# BGR.csv   FGN.csv   KASG.csv  KGPT.csv	KORC.csv  LXL.csv   SLG.csv
# BHB.csv   FIT.csv   KASL.csv  KGPZ.csv	KORE.csv  LXN.csv   SLH.csv
# BHK.csv   FKA.csv   KASW.csv  KGRI.csv	KORH.csv  LXT.csv   SLN.csv
# BIE.csv   FKS.csv   KASX.csv  KGRR.csv	KOSA.csv  LYO.csv   SME.csv
# BIH.csv   FLP.csv   KATY.csv  KGSH.csv	KOSC.csv  LYV.csv   SMN.csv
# BIL.csv   FME.csv   KAUG.csv  KGTF.csv	KOTG.csv  M02.csv   SMQ.csv
# BIV.csv   FMH.csv   KAUH.csv  KGTR.csv	KOTM.csv  M04.csv   SNH.csv
# BIX.csv   FMM.csv   KAUM.csv  KGUY.csv	KOVL.csv  M08.csv   SNY.csv
# BJI.csv   FNB.csv   KAVK.csv  KGWB.csv	KOVS.csv  M19.csv   SPD.csv
# BKB.csv   FNT.csv   KAWG.csv  KGWO.csv	KOWA.csv  M21.csv   SPF.csv
# BKN.csv   FOE.csv   KAXA.csv  KGWR.csv	KOWB.csv  M25.csv   SPW.csv
# BLM.csv   FOZ.csv   KAXN.csv  KGYL.csv	KOWD.csv  M30.csv   SRB.csv
# BLV.csv   FPK.csv   KAZC.csv  KHAE.csv	KOWP.csv  M40.csv   STC.csv
# BML.csv   FRH.csv   KAZO.csv  KHAI.csv	KOXB.csv  M54.csv   STF.csv
# BNA.csv   FRI.csv   KBAC.csv  KHAO.csv	KOXC.csv  M75.csv   STJ.csv
# BOS.csv   FRM.csv   KBAF.csv  KHBG.csv	KOXI.csv  M91.csv   STK.csv
# BPK.csv   FRR.csv   KBAN.csv  KHCD.csv	KOXV.csv  MAW.csv   STL.csv
# BQP.csv   FSD.csv   KBAX.csv  KHCO.csv	KOZW.csv  MBL.csv   STP.csv
# BRD.csv   FSE.csv   KBBB.csv  KHDC.csv	KP28.csv  MBO.csv   SUE.csv
# BRL.csv   FTK.csv   KBBG.csv  KHDE.csv	KP53.csv  MBS.csv   SUS.csv
# BRY.csv   FVE.csv   KBBW.csv  KHEF.csv	KP58.csv  MBY.csv   SUW.csv
# BTA.csv   FWB.csv   KBCK.csv  KHEQ.csv	KP59.csv  MCB.csv   SUX.csv
# BTL.csv   FWC.csv   KBDE.csv  KHEZ.csv	KP60.csv  MCD.csv   SWF.csv
# BTM.csv   FWN.csv   KBDH.csv  KHFD.csv	KP68.csv  MCI.csv   SYF.csv
# BTR.csv   FYE.csv   KBDL.csv  KHFJ.csv	KPAH.csv  MCK.csv   SYM.csv
# BVE.csv   FYG.csv   KBED.csv  KHGR.csv	KPDC.csv  MCW.csv   SYN.csv
# BVN.csv   FYV.csv   KBEH.csv  KHIB.csv	KPEA.csv  MDH.csv   SZL.csv
# BVO.csv   GAF.csv   KBFF.csv  KHIE.csv	KPEX.csv  MDJ.csv   SZT.csv
# BVU.csv   GAG.csv   KBFM.csv  KHJH.csv	KPHL.csv  MDPC.csv  SZY.csv
# BVX.csv   GAI.csv   KBFW.csv  KHKA.csv	KPHN.csv  MDT.csv   TAN.csv
# BVY.csv   GAO.csv   KBGR.csv  KHKS.csv	KPIB.csv  MEI.csv   TBN.csv
# BWG.csv   GBD.csv   KBHB.csv  KHLC.csv	KPKD.csv  MEM.csv   TCL.csv
# BWI.csv   GCC.csv   KBHK.csv  KHLN.csv	KPLN.csv  MEV.csv   TDZ.csv
# BWP.csv   GCK.csv   KBIE.csv  KHMZ.csv	KPMV.csv  MGC.csv   TEB.csv
# BXA.csv   GCM.csv   KBIH.csv  KHNB.csv	KPNC.csv  MGG.csv   TEW.csv
# BYG.csv   GCY.csv   KBIL.csv  KHND.csv	KPNE.csv  MGJ.csv   TGI.csv
# BYI.csv   GDB.csv   KBIV.csv  KHNR.csv	KPNM.csv  MGN.csv   THV.csv
# BYL.csv   GDV.csv   KBIX.csv  KHOP.csv	KPOF.csv  MGW.csv   TIF.csv
# BZN.csv   GED.csv   KBJI.csv  KHPN.csv	KPOU.csv  MGY.csv   TKC.csv
# C62.csv   GEY.csv   KBKB.csv  KHRO.csv	KPPF.csv  MHE.csv   TKX.csv
# C65.csv   GFA.csv   KBKN.csv  KHSA.csv	KPPO.csv  MHK.csv   TOB.csv
# CAD.csv   GFK.csv   KBLM.csv  KHSB.csv	KPPQ.csv  MHL.csv   TOL.csv
# CAR.csv   GFL.csv   KBML.csv  KHSI.csv	KPQI.csv  MHT.csv   TOP.csv
# CBE.csv   GGG.csv   KBNA.csv  KHTL.csv	KPQL.csv  MIC.csv   TOR.csv
# CBG.csv   GGW.csv   KBOS.csv  KHTS.csv	KPQN.csv  MIS.csv   TPH.csv
# CBK.csv   GHG.csv   KBPK.csv  KHUL.csv	KPSF.csv  MJQ.csv   TQE.csv
# CBM.csv   GHW.csv   KBQP.csv  KHUM.csv	KPTK.csv  MJX.csv   TRI.csv
# CDA.csv   GLD.csv   KBRD.csv  KHUT.csv	KPTN.csv  MKC.csv   TRK.csv
# CDC.csv   GLH.csv   KBRL.csv  KHVR.csv	KPTS.csv  MKG.csv   TTF.csv
# CDD.csv   GLR.csv   KBTA.csv  KHYA.csv	KPTT.csv  MKL.csv   TTN.csv
# CDJ.csv   GLW.csv   KBTL.csv  KHYS.csv	KPVC.csv  MKT.csv   TUL.csv
# CDR.csv   GLY.csv   KBTM.csv  KHYX.csv	KPVD.csv  MLE.csv   TUP.csv
# CDW.csv   GMJ.csv   KBTR.csv  KHZR.csv	KPWC.csv  MLF.csv   TVC.csv
# CEF.csv   GNA.csv   KBVE.csv  KHZX.csv	KPWM.csv  MLP.csv   TVF.csv
# CERM.csv  GNR.csv   KBVN.csv  KI16.csv	KPYM.csv  MLS.csv   TVL.csv
# CEY.csv   GOV.csv   KBVO.csv  KI35.csv	KPYX.csv  MLT.csv   TVR.csv
# CFE.csv   GPH.csv   KBVU.csv  KI69.csv	KPZQ.csv  MLU.csv   TWF.csv
# CFS.csv   GPI.csv   KBVX.csv  KI75.csv	KRCM.csv  MMH.csv   TWM.csv
# CFV.csv   GPT.csv   KBVY.csv  KIAD.csv	KRDK.csv  MMIO.csv  TXK.csv
# CGE.csv   GPZ.csv   KBWG.csv  KIBM.csv	KREO.csv  MMK.csv   U68.csv
# CGI.csv   GRI.csv   KBWI.csv  KICL.csv	KRGK.csv  MML.csv   UCY.csv
# CGS.csv   GRN.csv   KBWP.csv  KICR.csv	KRHI.csv  MMU.csv   UIN.csv
# CIR.csv   GRR.csv   KBXA.csv  KICT.csv	KRKD.csv  MMUN.csv  UKT.csv
# CIU.csv   GSH.csv   KBYG.csv  KIDP.csv	KRMN.csv  MNE.csv   ULM.csv
# CKB.csv   GTF.csv   KBYI.csv  KIEN.csv	KRMY.csv  MNM.csv   ULS.csv
# CKC.csv   GTR.csv   KBZN.csv  KIER.csv	KRNH.csv  MOB.csv   UNI.csv
# CKM.csv   GUY.csv   KCAD.csv  KIFP.csv	KRNO.csv  MOP.csv   UNO.csv
# CKN.csv   GWB.csv   KCAR.csv  KIGM.csv	KRNP.csv  MOR.csv   UOX.csv
# CKV.csv   GWO.csv   KCBE.csv  KIJD.csv	KRNV.csv  MPO.csv   USE.csv
# CKZ.csv   GWR.csv   KCBF.csv  KIJX.csv	KROG.csv  MPV.csv   UTA.csv
# CMFM.csv  GYL.csv   KCBG.csv  KIKW.csv	KROS.csv  MQB.csv   UUU.csv
# CMGB.csv  HAE.csv   KCBK.csv  KILG.csv	KROX.csv  MQE.csv   UXL.csv
# CMX.csv   HAI.csv   KCBM.csv  KILN.csv	KRQB.csv  MQS.csv   VAY.csv
# CMY.csv   HAO.csv   KCCY.csv  KIML.csv	KRRT.csv  MRB.csv   VBT.csv
# CNB.csv   HBG.csv   KCDA.csv  KIMT.csv	KRSL.csv  MROC.csv  VER.csv
# CNK.csv   HCD.csv   KCDC.csv  KINL.csv	KRSN.csv  MSL.csv   VGT.csv
# CNU.csv   HCO.csv   KCDD.csv  KIOB.csv	KRST.csv  MSO.csv   VIH.csv
# COD.csv   HDC.csv   KCDJ.csv  KIRK.csv	KRTS.csv  MSP.csv   VJI.csv
# CON.csv   HDE.csv   KCDR.csv  KIRS.csv	KRUT.csv  MSV.csv   VKS.csv
# COQ.csv   HEF.csv   KCDW.csv  KISN.csv	KRWF.csv  MSY.csv   VLL.csv
# COU.csv   HEQ.csv   KCEY.csv  KISQ.csv	KRXE.csv  MTC.csv   VPZ.csv
# CPBT.csv  HEZ.csv   KCFE.csv  KITR.csv	KRZN.csv  MTN.csv   VSF.csv
# CPFI.csv  HFD.csv   KCFS.csv  KIWD.csv	KS25.csv  MUO.csv   VTN.csv
# CPRY.csv  HFJ.csv   KCGE.csv  KIWI.csv	KS32.csv  MVE.csv   VVV.csv
# CPS.csv   HGR.csv   KCGI.csv  KIXD.csv	KSAR.csv  MVH.csv   VWU.csv
# CPSV.csv  HIB.csv   KCGS.csv  KIYA.csv	KSAW.csv  MVL.csv   W22.csv
# CPXL.csv  HIE.csv   KCIR.csv  KIZG.csv	KSAZ.csv  MVY.csv   W29.csv
# CQM.csv   HII.csv   KCIU.csv  KJAC.csv	KSBN.csv  MWA.csv   W43.csv
# CQX.csv   HJH.csv   KCKB.csv  KJAN.csv	KSBY.csv  MWM.csv   W99.csv
# CRX.csv   HKA.csv   KCKC.csv  KJAS.csv	KSCF.csv  MWN.csv   WAL.csv
# CTB.csv   HKS.csv   KCKM.csv  KJBR.csv	KSCH.csv  MWO.csv   WDG.csv
# CTRA.csv  HLB.csv   KCKN.csv  KJDN.csv	KSDA.csv  MYJ.csv   WLD.csv
# CUL.csv   HLC.csv   KCKP.csv  KJEF.csv	KSDF.csv  MYZ.csv   WMC.csv
# CVG.csv   HLN.csv   KCKV.csv  KJER.csv	KSDY.csv  MZH.csv   WRI.csv
# CVW.csv   HMZ.csv   KCMX.csv  KJFK.csv	KSET.csv  NAK.csv   WVL.csv
# CVX.csv   HNB.csv   KCMY.csv  KJFZ.csv	KSFM.csv  NBG.csv   WWR.csv
# CWAF.csv  HND.csv   KCNB.csv  KJKJ.csv	KSFZ.csv  NEL.csv   WYS.csv
# CWAJ.csv  HOP.csv   KCNC.csv  KJKL.csv	KSGF.csv  NEW.csv   XLL.csv
# CWAQ.csv  HPN.csv   KCNK.csv  KJLN.csv	KSGS.csv  NFL.csv   XNA.csv
# CWDV.csv  HQG.csv   KCNU.csv  KJMR.csv	KSGT.csv  NHK.csv   XNX.csv
# CWEH.csv  HRO.csv   KCOD.csv  KJST.csv	KSGU.csv  NMM.csv   XPY.csv
# CWER.csv  HSA.csv   KCON.csv  KJVW.csv	KSHL.csv  NQA.csv   XVG.csv
# CWF.csv   HSB.csv   KCOQ.csv  KJXN.csv	KSHR.csv  NUI.csv   Y31.csv
# CWFJ.csv  HSI.csv   KCOU.csv  KJYG.csv	KSHV.csv  NYC.csv   Y49.csv
# CWGM.csv  HTH.csv   KCPS.csv  KJYM.csv	KSJS.csv  NYG.csv   Y51.csv
# CWGW.csv  HTL.csv   KCQM.csv  KJYO.csv	KSJX.csv  OCQ.csv   Y63.csv
# CWHV.csv  HTS.csv   KCQX.csv  KJYR.csv	KSLB.csv  ODX.csv   Y70.csv
# CWIG.csv  HUL.csv   KCRX.csv  KLAA.csv	KSLG.csv  OEB.csv   YIP.csv
# CWIS.csv  HUM.csv   KCSQ.csv  KLAN.csv	KSLH.csv  OEO.csv   YKN.csv
# CWJB.csv  HUT.csv   KCTB.csv  KLAS.csv	KSME.csv  OFF.csv
# CWJI.csv  HVR.csv   KCUL.csv  KLBE.csv	KSMN.csv  OFK.csv
# CWJR.csv  HYA.csv   KCVG.csv  KLBF.csv	KSMQ.csv  OGA.csv
# CWKO.csv  HYS.csv   KCVX.csv  KLBL.csv	KSNY.csv  OJC.csv
# CWMQ.csv  HYX.csv   KCWF.csv  KLCG.csv	KSPD.csv  OKV.csv
# CWNH.csv  HZD.csv   KCXP.csv  KLCH.csv	KSPF.csv  OLF.csv

# %%
def add_data_to_asos(asos_file_dir):
  for

# %%
# !ls
# Out:
# adc.json  gage_data  record.json  sample_data

# %%
# !ls -1 gage_data | wc -l
# Out:
# 6059
