# %%
import os
import pandas as pd
from google.colab import auth
from datetime import datetime
import requests
import json
auth.authenticate_user()
# !gsutil -m cp -r gs://predict_cfs/revised_metadata .
# !mkdir end_data
def get_elevation_Data(l1, l2, key):
  url = "https://maps.googleapis.com/maps/api/elevation/json?locations={},{}&key={}".format(l1, l2, key)
  resp = requests.get(url)
  return json.loads(resp.text)
def get_soil_grids(l1, l2):
  url = "https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon={}&lat={}&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.05&value=Q0.5&value=Q0.95&value=mean&value=uncertainty"
  final_url = url.format(l2, l1)
  resp = requests.get(final_url)
  return json.loads(resp.text)
# Out:
# Streaming output truncated to the last 5000 lines.
# Copying gs://predict_cfs/revised_metadata/gage_data/14171600stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14172000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14174000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1417500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14178000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14178700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14179000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14179100stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14180510stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14180300stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14181410stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14181500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14181750stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14182400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14182500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14183000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14184100stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14185700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14185900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14185000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14185800stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14186110stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14186200stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14186610stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14187000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14187200stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14187500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14187600stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14188610stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14188800stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14189000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14190500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14191000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14192500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14193000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14194000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14194150stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14194300stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1419500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14197900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14198400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14196000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14198500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14199704stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14200100stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14200000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14200300stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14200400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14200700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14201300stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14201340stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14201500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14202000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14202550stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14202630stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14202650stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14202980stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14203500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14203750stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1420500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14205400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14206900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14206950stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14207000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14207740stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14207500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14207770stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14208700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14209000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14209250stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14209500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14209700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14210000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1420980stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1421000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14211010stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14211315stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14211400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14211499stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14211500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14211542stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14211550stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14211720stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14211814stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14211820stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14211895stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14211898stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14211901stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14211902stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14216000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1421610stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1421618stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14216500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14219000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1421900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14219800stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14220500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14222500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1422389stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1422500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14226500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1422738stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1422747stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1422779stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14231000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1423000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14231900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14232500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14233400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14233500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14236200stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14238000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/142400103stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14240311stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14240525stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1424108stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14241100stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14241500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14243000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14242580stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14246900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1425000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1426500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1427195stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1427207stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1427500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1428000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1427510stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1428750stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1428500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1429000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1429301stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1429500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14299800stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1430000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14301000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14301500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14302020stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14302480stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14302900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14303200stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14303600stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14304350stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14306030stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14305500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14306100stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14306340stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14306400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14306500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14306900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14307580stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14307620stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14308000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14308500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14308600stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14308990stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14309000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14309500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14310000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14311500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14312000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14312170stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14312500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14313500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14313200stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14313700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14314500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14314700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1431500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14315500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14315700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14315950stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14316000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1431620stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14316455stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14316495stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14316500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14316700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1431683stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1431685stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14318000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14319500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14319835stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14319830stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14320700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14319850stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14320934stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14321000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1432110stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14321400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1432160stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1432495stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14325000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14326510stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14327000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14327055stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14327250stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14328000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1432900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14330000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1433005stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14334700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14332000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1433500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14335072stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14335200stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14335500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14337500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14337800stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14337830stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14337600stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14337870stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14338000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14339000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1434000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/143400680stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1434013stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1434017stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1434021stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/143402265stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1434025stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1434072stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1434073stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1434080stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1434084stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1434086stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1434105stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1434176stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14342500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1434498stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1434087stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14348430stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1435000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14353000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14353500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14354200stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14357500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14359000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1436000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14361500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14362000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14362250stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14365400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1436500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14366000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1436690stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14369500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14371500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14372300stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14372500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1437500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14375100stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14375400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14377100stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14378430stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1438500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1439500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1439590stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1439800stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/14400000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1440000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1440200stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1440400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1440485stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1441495stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1442500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1443280stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1443500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1443900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1445000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/
ations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1615000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1616000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1616100stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1616400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1617000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1616425stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1618000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1616500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1618100stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1620500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1621410stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1622000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1621050stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1621470stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1622464stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/162246784stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/1625000stations.json...
# ...
# Copying gs://predict_cfs/revised_metadata/gage_data/9188500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9186500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9187550stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9196500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9196940stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9196960stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9197000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9203000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9205000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9209400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9208400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9210500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9211200stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9213500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9215000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9215550stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9216050stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9217000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9217900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9218500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9219200stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9220000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9222400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9223000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9223385stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9224700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9230300stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9235100stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9234500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9229500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9235600stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9256000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9257000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9258050stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9258980stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9259000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9261000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9261700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9265500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9266500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9267500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9268500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9268900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9270500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9271400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9271425stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9271450stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9271550stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9272400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9274900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9275500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9276600stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9277500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9277800stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9278000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9278500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9279000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9279100stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9279150stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9285000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9285900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9286700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9286100stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9288000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9288180stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9288400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9289500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9291000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9292000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9292500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9295000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9295100stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9296800stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9299500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9299400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9302000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9306500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9301500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9306800stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9308500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9309600stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9310000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9310500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9312600stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9310700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9312700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9312800stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9313000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9314280stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9314500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9315000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9319000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9323000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9326500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9327000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9328060stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9328500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9328920stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9328910stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9328990stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9329050stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9330000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9330230stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9330410stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9330500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9332800stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9332100stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9332600stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9333500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9335200stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9337000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9337500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9338900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9339000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9346050stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9355500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9357245stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9357255stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9364010stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9365000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9364500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9367500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9367000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9367536stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9367540stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9367580stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9367950stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9368000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9372400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9376800stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9378170stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9378200stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9378630stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9378600stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9378650stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9378700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9379500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9381500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9381800stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9386910stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9386900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9386915stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9386917stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9386919stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9386950stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9386925stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9395350stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9395630stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9403600stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9403690stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9404450stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9404700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9404900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9405490stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9405499stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9405500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9405501stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9405900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9406000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9406150stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9406100stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9406640stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9406700stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9406900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9407000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9407810stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9408000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9408135stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9408175stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9408150stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9408195stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9408400stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9408500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9409100stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9409880stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9410100stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9413000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9413200stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9413900stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9413500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9430010stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9429980stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9430020stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9430030stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9430500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9430600stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9430815stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9430820stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9430825stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9431500stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9431503stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9432000stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9442625stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9442661stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9442662stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9442666stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9442667stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9442669stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9442677stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9442680stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9442681stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9442683stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9442684stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9442682stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9442692stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9442704stations.json...
# Copying gs://predict_cfs/revised_metadata/gage_data/9442755stations.json...
# - [9.0k/9.0k files][ 12.8 MiB/ 12.8 MiB] 100% Done  39.9 KiB/s ETA 00:00:00
# Operation completed over 9.0k objects/12.8 MiB.
# mkdir: cannot create directory ‘end_data’: File exists

# %%
# !mkdir end_dat

# %%
def loop_through(key, dir="revised_data", start_idx=246, end_idx=1000):
  files = os.listdir(dir) 
  for f in range(start_idx, end_idx):
    with open(os.path.join(dir, files[f])) as file1:
      data = json.load(file1)
    if "latitude" in data:
      lat = data["latitude"]
      lng = data["longitude"]
      data["goog_el"] = get_elevation_Data(lat, lng, key)
      data["soil"] = get_soil_grids(lat, lng)
      with open(os.path.join("end_dat", files[f]), "w+") as y:
        json.dump(data, y)
    else: 
      print("Error for" + files[f])
    
# !mkdir end_dat
key = "put_key_here"
loop_through(key, "revised_metadata")
# Out:
# mkdir: cannot create directory ‘end_dat’: File exists
# Error for73816505stations.json
# Error for11055525stations.json
# Error for73745245stations.json
# Error for412220999stations.json
# Error for738022395stations.json
# Error for1105883757stations.json
# Error for41482663stations.json
# Error for40975299stations.json
# Error for73816501stations.json
# Error for94196497stations.json
# Error for73802225stations.json
# Error for158935180stations.json
# Error for94196557stations.json
# Error for40445315stations.json
# Error for73815945stations.json
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-88-a94e842e551c> in <module>()
#      16 get_ipython().system('mkdir end_dat')
#      17 key = "AIzaSyCo_2dKDCWzdspUpgr2cWF2LIDZdCEetk0"
# ---> 18 loop_through(key, "revised_metadata")
#
# <ipython-input-88-a94e842e551c> in loop_through(key, dir, start_idx, end_idx)
#       2   files = os.listdir(dir)
#       3   for f in range(start_idx, end_idx):
# ----> 4     with open(os.path.join(dir, files[f])) as file1:
#       5       data = json.load(file1)
#       6     if "latitude" in data:
#
# IsADirectoryError: [Errno 21] Is a directory: 'revised_metadata/gage_data'

# %%
# !gsutil cp -r end_dat gs://predict_cfs/meta_soil

# %%
# !gsutil cp -r end_dat gs://predict_cfs/meta_soil
# Out:
# '{"detail":[{"loc":["query","lat"],"msg":"ensure this value is greater than or equal to -90.0","type":"value_error.number.not_ge","ctx":{"limit_value":-90.0}}]}'

# %%
with open('revised_metadata/1111212stations.json') as y:
  data =json.load(y)
print(data)
# Out:
# {'gage_id': 1111212, 'stations': [{'station_id': 'SFZ', 'dist': 18.140337131301568, 'cat': 'ASOS', 'missing_temp': 212135, 'missing_precip': 192893}, {'station_id': 'KSFZ', 'dist': 18.17133860668529, 'cat': 'ASOS', 'missing_temp': 212135, 'missing_precip': 192893}, {'station_id': 'ORH', 'dist': 31.860095867215463, 'cat': 'ASOS', 'missing_temp': 225224, 'missing_precip': 209662}, {'station_id': 'KORH', 'dist': 31.98685035204759, 'cat': 'ASOS', 'missing_temp': 225224, 'missing_precip': 209662}, {'station_id': 'KOWD', 'dist': 39.53058702564567, 'cat': 'ASOS', 'missing_temp': 232873, 'missing_precip': 219306}, {'station_id': 'OWD', 'dist': 39.574177951536804, 'cat': 'ASOS', 'missing_temp': 232873, 'missing_precip': 219306}, {'station_id': 'KPVD', 'dist': 40.02847126174439, 'cat': 'ASOS', 'missing_temp': 233270, 'missing_precip': 218330}, {'station_id': 'PVD', 'dist': 40.02847126174439, 'cat': 'ASOS', 'missing_temp': 233270, 'missing_precip': 218330}, {'station_id': 'MQE', 'dist': 44.95808970940626, 'cat': 'ASOS', 'missing_temp': 646, 'missing_precip': 0}, {'station_id': 'KTAN', 'dist': 53.105144657135725, 'cat': 'ASOS', 'missing_temp': 217329, 'missing_precip': 203981}, {'station_id': 'TAN', 'dist': 53.105144657135725, 'cat': 'ASOS', 'missing_temp': 217329, 'missing_precip': 203981}, {'station_id': 'KBED', 'dist': 53.43661766074176, 'cat': 'ASOS', 'missing_temp': 233597, 'missing_precip': 219554}], 'latitude': 42.05481959, 'longitude': -71.6164542}

# %% [markdown]
# ## Getting data

# %%
# !gsutil du gs://predict_cfs/revised_metadata_final | wc -l
# Out:
# 3882

# %%
# !gsutil du gs://predict_cfs/meta_data/distance3| wc -l
# Out:
# 3882
