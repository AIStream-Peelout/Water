# %%
import json
import sys
sys.path.append('/Users/gisaac/Documents/GitHub/river_flow_notebooks/')

with open("scan_11059300.json") as f:
    data = json.load(f)

# %%
from scraping_functions import HydroScraper

# %%
from datetime import datetime
h = HydroScraper(datetime(1989, 1, 1), datetime(2024, 1, 18), "scan_11059300.json")
# Out:
# Getting request from USGS
# http://waterservices.usgs.gov/nwis/iv/?format=rdb,1.0&sites=11059300&startDT=1989-01-01&endDT=2024-01-18&parameterCd=00060,00065,00045&siteStatus=all
# Request finished
# /Users/gisaac/Documents/GitHub/river_flow_notebooks/scraping_functions.py:92: DtypeWarning: Columns (1,4,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, sep="\t")
# /Users/gisaac/Documents/GitHub/river_flow_notebooks/scraping_functions.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["datetime"] = df["datetime"].map(lambda x: old_timezone.localize(datetime.strptime(x, "%Y-%m-%d %H:%M")).astimezone(new_timezone))
# /Users/gisaac/Documents/GitHub/river_flow_notebooks/scraping_functions.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["cfs"] = pd.to_numeric(df['cfs'], errors='coerce')
# /Users/gisaac/Documents/GitHub/river_flow_notebooks/weather_scraping_functions.py:31: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path) # , parse_dates=['valid']
#        station             valid   tmpf   dwpf p01m     mslp    drct  \
# 0          SBD  1989-01-01 00:00  48.00  42.00    M  1014.80  340.00
# 1          SBD  1989-01-01 01:00  47.00  42.00    M  1014.80  330.00
# 2          SBD  1989-01-01 02:00  46.00  42.00    M  1015.00    0.00
# 3          SBD  1989-01-01 03:00  45.00  43.00    M  1014.70    0.00
# 4          SBD  1989-01-01 04:00  45.00  43.00    M  1014.80    0.00
# ...        ...               ...    ...    ...  ...      ...     ...
# 192899     SBD  2024-01-18 04:00  55.40  46.40  0.0        M  240.00
# 192900     SBD  2024-01-18 04:55  55.40  46.40  0.0        M  240.00
# 192901     SBD  2024-01-18 05:40  54.70  46.60  0.0        M    0.00
# 192902     SBD  2024-01-18 06:00  55.00  46.80  0.0        M    0.00
# 192903     SBD  2024-01-18 06:20  54.50  46.60  0.0        M    0.00
#
#        ice_accretion_1hr
# 0                      M
# 1                      M
# 2                      M
# 3                      M
# 4                      M
# ...                  ...
# 192899                 M
# 192900                 M
# 192901                 M
# 192902                 M
# 192903                 M
#
# [192904 rows x 8 columns]
#        station             valid  tmpf  dwpf  p01m     mslp    drct  \
# 0          SBD  1989-01-01 00:00  48.0  42.0   NaN  1014.80  340.00
# 1          SBD  1989-01-01 01:00  47.0  42.0   NaN  1014.80  330.00
# 2          SBD  1989-01-01 02:00  46.0  42.0   NaN  1015.00    0.00
# 3          SBD  1989-01-01 03:00  45.0  43.0   NaN  1014.70    0.00
# 4          SBD  1989-01-01 04:00  45.0  43.0   NaN  1014.80    0.00
# ...        ...               ...   ...   ...   ...      ...     ...
# 192899     SBD  2024-01-18 04:00  55.4  46.4   0.0        M  240.00
# 192900     SBD  2024-01-18 04:55  55.4  46.4   0.0        M  240.00
# 192901     SBD  2024-01-18 05:40  54.7  46.6   0.0        M    0.00
# 192902     SBD  2024-01-18 06:00  55.0  46.8   0.0        M    0.00
# 192903     SBD  2024-01-18 06:20  54.5  46.6   0.0        M    0.00
#
#        ice_accretion_1hr        hour_updated
# 0                      M 1989-01-01 00:00:00
# 1                      M 1989-01-01 01:00:00
# 2                      M 1989-01-01 02:00:00
# 3                      M 1989-01-01 03:00:00
# 4                      M 1989-01-01 04:00:00
# ...                  ...                 ...
# 192899                 M 2024-01-18 04:00:00
# 192900                 M 2024-01-18 05:00:00
# 192901                 M 2024-01-18 06:00:00
# 192902                 M 2024-01-18 06:00:00
# 192903                 M 2024-01-18 07:00:00
#
# [192904 rows x 9 columns]
#         Unnamed: 0         hour_updated  p01m             valid   tmpf  dwpf  \
# 0                0  1989-01-01 00:00:00   0.0  1989-01-01 00:00  48.00  42.0
# 1                1  1989-01-01 01:00:00   0.0  1989-01-01 01:00  47.00  42.0
# 2                2  1989-01-01 02:00:00   0.0  1989-01-01 02:00  46.00  42.0
# 3                3  1989-01-01 03:00:00   0.0  1989-01-01 03:00  45.00  43.0
# 4                4  1989-01-01 04:00:00   0.0  1989-01-01 04:00  45.00  43.0
# ...            ...                  ...   ...               ...    ...   ...
# 139730      139730  2024-01-18 02:00:00   0.0  2024-01-18 01:51  55.40  44.6
# 139731      139731  2024-01-18 04:00:00   0.0  2024-01-18 03:55  55.40  46.4
# 139732      139732  2024-01-18 05:00:00   0.0  2024-01-18 04:55  55.40  46.4
# 139733      139733  2024-01-18 06:00:00   0.0  2024-01-18 05:40  54.85  46.7
# 139734      139734  2024-01-18 07:00:00   0.0  2024-01-18 06:20  54.50  46.6
#
#        ice_accretion_1hr     mslp    drct
# 0                      M  1014.80  340.00
# 1                      M  1014.80  330.00
# 2                      M  1015.00    0.00
# 3                      M  1014.70    0.00
# 4                      M  1014.80    0.00
# ...                  ...      ...     ...
# 139730                 M        M  240.00
# 139731                 M        M  240.00
# 139732                 M        M  240.00
# 139733                 M        M    0.00
# 139734                 M        M    0.00
#
# [139735 rows x 9 columns]
#         Unnamed: 0        hour_updated  p01m             valid   tmpf  dwpf  \
# 0                0 1989-01-01 00:00:00   0.0  1989-01-01 00:00  48.00  42.0
# 1                1 1989-01-01 01:00:00   0.0  1989-01-01 01:00  47.00  42.0
# 2                2 1989-01-01 02:00:00   0.0  1989-01-01 02:00  46.00  42.0
# 3                3 1989-01-01 03:00:00   0.0  1989-01-01 03:00  45.00  43.0
# 4                4 1989-01-01 04:00:00   0.0  1989-01-01 04:00  45.00  43.0
# ...            ...                 ...   ...               ...    ...   ...
# 139730      139730 2024-01-18 02:00:00   0.0  2024-01-18 01:51  55.40  44.6
# 139731      139731 2024-01-18 04:00:00   0.0  2024-01-18 03:55  55.40  46.4
# 139732      139732 2024-01-18 05:00:00   0.0  2024-01-18 04:55  55.40  46.4
# 139733      139733 2024-01-18 06:00:00   0.0  2024-01-18 05:40  54.85  46.7
# 139734      139734 2024-01-18 07:00:00   0.0  2024-01-18 06:20  54.50  46.6
#
#        ice_accretion_1hr     mslp    drct
# 0                      M  1014.80  340.00
# 1                      M  1014.80  330.00
# 2                      M  1015.00    0.00
# 3                      M  1014.70    0.00
# 4                      M  1014.80    0.00
# ...                  ...      ...     ...
# 139730                 M        M  240.00
# 139731                 M        M  240.00
# 139732                 M        M  240.00
# 139733                 M        M    0.00
# 139734                 M        M    0.00
#
# [139735 rows x 9 columns]
# Scraping completed

# %%
h.combine_data()

# %%
h.joined_df
# Out:
#                     hour_updated  p01m             valid   tmpf  dwpf  \
# 0      1989-02-03 08:00:00+00:00   0.0  1989-02-03 08:00  48.00  41.0
# 1      1989-02-03 09:00:00+00:00   0.0  1989-02-03 08:50  48.00  42.0
# 2      1989-02-03 10:00:00+00:00   0.0  1989-02-03 09:12  48.00  42.0
# 3      1989-02-03 11:00:00+00:00   0.0  1989-02-03 11:00  48.00  42.0
# 4      1989-02-03 12:00:00+00:00   0.0  1989-02-03 12:00  48.00  42.0
# ...                          ...   ...               ...    ...   ...
# 115793 2024-01-18 00:00:00+00:00   0.0  2024-01-17 23:53  60.80  44.6
# 115794 2024-01-18 02:00:00+00:00   0.0  2024-01-18 01:51  55.40  44.6
# 115795 2024-01-18 04:00:00+00:00   0.0  2024-01-18 03:55  55.40  46.4
# 115796 2024-01-18 05:00:00+00:00   0.0  2024-01-18 04:55  55.40  46.4
# 115797 2024-01-18 06:00:00+00:00   0.0  2024-01-18 05:40  54.85  46.7
#
#        ice_accretion_1hr     mslp    drct    index agency_cd   site_no  \
# 0                      M  1022.10    0.00        1      USGS  11059300
# 1                      M        M    0.00        5      USGS  11059300
# 2                      M        M    0.00        9      USGS  11059300
# 3                      M  1021.60    0.00       13      USGS  11059300
# 4                      M  1021.40    0.00       17      USGS  11059300
# ...                  ...      ...     ...      ...       ...       ...
# 115793                 M        M    0.00  1011071      USGS  11059300
# 115794                 M        M  240.00  1011079      USGS  11059300
# 115795                 M        M  240.00  1011087      USGS  11059300
# 115796                 M        M  240.00  1011091      USGS  11059300
# 115797                 M        M    0.00  1011095      USGS  11059300
#
#                         datetime tz_cd   cfs 14206_00060_cd height  \
# 0      1989-02-03 08:00:00+00:00   PST  41.0         A:[91]    NaN
# 1      1989-02-03 09:00:00+00:00   PST  51.0         A:[91]    NaN
# 2      1989-02-03 10:00:00+00:00   PST  44.0         A:[91]    NaN
# 3      1989-02-03 11:00:00+00:00   PST  44.0         A:[91]    NaN
# 4      1989-02-03 12:00:00+00:00   PST  33.0         A:[91]    NaN
# ...                          ...   ...   ...            ...    ...
# 115793 2024-01-18 00:00:00+00:00   PST  25.5              P   2.89
# 115794 2024-01-18 02:00:00+00:00   PST  25.5              P   2.89
# 115795 2024-01-18 04:00:00+00:00   PST  28.6              P   2.91
# 115796 2024-01-18 05:00:00+00:00   PST  37.4              P   2.97
# 115797 2024-01-18 06:00:00+00:00   PST  25.5              P   2.89
#
#        14207_00065_cd
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 115793              P
# 115794              P
# 115795              P
# 115796              P
# 115797              P
#
# [115798 rows x 17 columns]

# %%
h.combine_snotel_with_df()
# Out:
# The base URL for SNOTEL is below:
# https://powderlines.kellysoftware.org/api/station/1110:NV:SNTL?start_date=1989-01-01&end_date=2024-01-18

# %%
h.final_df.to_csv("s11059300_89_24.csv")

# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/gisaac/Documents/GitHub/river_flow_notebooks/notebook_etl_building

# %%
sentinel_df = pd.read_csv("/Users/gisaac/Downloads/sent_data.csv")

# %%
h.combine_sentinel(sentinel_df)
h.final_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 h.combine_sentinel(sentinel_df)
#       2 h.final_df
#
# File ~/Documents/GitHub/river_flow_notebooks/scraping_functions.py:141, in HydroScraper.combine_sentinel(self, sentinel_df)
#     138 def combine_sentinel(self, sentinel_df):
#     139     """ to combine the Sentinel data with the joined ASOS, USGS, and SNOTEL data.
#     140     """
# --> 141     self.sentinel_df = sentinel_df[["SENSING_TIME", "BASE_URL"]]
#     142     self.sentinel_df["SENSING_TIME"] = pd.to_datetime(self.sentinel_df["SENSING_TIME"], utc=True)
#     143     self.final_df = self.final_df.merge(self.sentinel_df, left_on="hour_updated", right_on="SENSING_TIME", how="left")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5936     if use_interval_msg:
#    5937         key = list(key)
# -> 5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['SENSING_TIME', 'BASE_URL'], dtype='object')] are in the [columns]"

# %%
def combine_sentinel(final_df, sentinel_df, tile):
    """ to combine the Sentinel data with the joined ASOS, USGS, and SNOTEL data.
    """
    sentinel_df = sentinel_df[sentinel_df["mgrs_tile"]==tile] 
    sentinel_df = sentinel_df[["sensing_time", "base_url"]]
    sentinel_df["SENSING_TIME"] = pd.to_datetime(sentinel_df["sensing_time"], utc=True, format='mixed').round('60min')
    final_df =final_df.merge(sentinel_df, left_on="hour_updated", right_on="SENSING_TIME", how="left")
    return final_df

fin_df = combine_sentinel(h.final_df, sentinel_df, "11SMT")
fin_df
# Out:
#                     hour_updated  p01m             valid   tmpf  dwpf  \
# 0      1989-02-03 08:00:00+00:00   0.0  1989-02-03 08:00  48.00  41.0
# 1      1989-02-03 09:00:00+00:00   0.0  1989-02-03 08:50  48.00  42.0
# 2      1989-02-03 10:00:00+00:00   0.0  1989-02-03 09:12  48.00  42.0
# 3      1989-02-03 11:00:00+00:00   0.0  1989-02-03 11:00  48.00  42.0
# 4      1989-02-03 12:00:00+00:00   0.0  1989-02-03 12:00  48.00  42.0
# ...                          ...   ...               ...    ...   ...
# 115831 2024-01-18 00:00:00+00:00   0.0  2024-01-17 23:53  60.80  44.6
# 115832 2024-01-18 02:00:00+00:00   0.0  2024-01-18 01:51  55.40  44.6
# 115833 2024-01-18 04:00:00+00:00   0.0  2024-01-18 03:55  55.40  46.4
# 115834 2024-01-18 05:00:00+00:00   0.0  2024-01-18 04:55  55.40  46.4
# 115835 2024-01-18 06:00:00+00:00   0.0  2024-01-18 05:40  54.85  46.7
#
#        ice_accretion_1hr     mslp    drct    index agency_cd  ... Date  \
# 0                      M  1022.10    0.00        1      USGS  ...  NaT
# 1                      M        M    0.00        5      USGS  ...  NaT
# 2                      M        M    0.00        9      USGS  ...  NaT
# 3                      M  1021.60    0.00       13      USGS  ...  NaT
# 4                      M  1021.40    0.00       17      USGS  ...  NaT
# ...                  ...      ...     ...      ...       ...  ...  ...
# 115831                 M        M    0.00  1011071      USGS  ...  NaT
# 115832                 M        M  240.00  1011079      USGS  ...  NaT
# 115833                 M        M  240.00  1011087      USGS  ...  NaT
# 115834                 M        M  240.00  1011091      USGS  ...  NaT
# 115835                 M        M    0.00  1011095      USGS  ...  NaT
#
#        Snow Water Equivalent (in) Change In Snow Water Equivalent (in)  \
# 0                             NaN                                  NaN
# 1                             NaN                                  NaN
# 2                             NaN                                  NaN
# 3                             NaN                                  NaN
# 4                             NaN                                  NaN
# ...                           ...                                  ...
# 115831                        NaN                                  NaN
# 115832                        NaN                                  NaN
# 115833                        NaN                                  NaN
# 115834                        NaN                                  NaN
# 115835                        NaN                                  NaN
#
#         Snow Depth (in) Change In Snow Depth (in)  \
# 0                   NaN                       NaN
# 1                   NaN                       NaN
# 2                   NaN                       NaN
# 3                   NaN                       NaN
# 4                   NaN                       NaN
# ...                 ...                       ...
# 115831              NaN                       NaN
# 115832              NaN                       NaN
# 115833              NaN                       NaN
# 115834              NaN                       NaN
# 115835              NaN                       NaN
#
#        Observed Air Temperature (degrees farenheit) filled_snow sensing_time  \
# 0                                               NaN          23          NaN
# 1                                               NaN          23          NaN
# 2                                               NaN          23          NaN
# 3                                               NaN          23          NaN
# 4                                               NaN          23          NaN
# ...                                             ...         ...          ...
# 115831                                          NaN           3          NaN
# 115832                                          NaN           3          NaN
# 115833                                          NaN           3          NaN
# 115834                                          NaN           3          NaN
# 115835                                          NaN           3          NaN
#
#        base_url SENSING_TIME
# 0           NaN          NaT
# 1           NaN          NaT
# 2           NaN          NaT
# 3           NaN          NaT
# 4           NaN          NaT
# ...         ...          ...
# 115831      NaN          NaT
# 115832      NaN          NaT
# 115833      NaN          NaT
# 115834      NaN          NaT
# 115835      NaN          NaT
#
# [115836 rows x 27 columns]

# %%
fin_df.dropna(subset=["base_url"])
# Out:
#                     hour_updated  p01m             valid  tmpf  dwpf  \
# 58954  2015-08-10 19:00:00+00:00   0.0  2015-08-10 18:47  75.2  53.6
# 59086  2015-08-20 19:00:00+00:00   0.0  2015-08-20 18:47  75.2  57.2
# 59253  2015-09-02 19:00:00+00:00   0.0  2015-09-02 18:47  77.0  53.6
# 59345  2015-09-09 19:00:00+00:00   0.0  2015-09-09 18:48  98.6  53.6
# 59480  2015-09-19 19:00:00+00:00   0.0  2015-09-19 18:50  93.2  37.4
# ...                          ...   ...               ...   ...   ...
# 115622 2024-01-08 19:00:00+00:00   0.0  2024-01-08 18:51  53.6  10.4
# 115669 2024-01-10 19:00:00+00:00   0.0  2024-01-10 18:54  53.6  32.0
# 115670 2024-01-10 19:00:00+00:00   0.0  2024-01-10 18:54  53.6  32.0
# 115737 2024-01-13 19:00:00+00:00   0.0  2024-01-13 18:51  55.4  26.6
# 115781 2024-01-15 19:00:00+00:00   0.0  2024-01-15 18:51  57.2  39.2
#
#        ice_accretion_1hr mslp    drct    index agency_cd  ... Date  \
# 58954                  M    M  220.00   754513      USGS  ...  NaT
# 59086                  M    M  300.00   755473      USGS  ...  NaT
# 59253                  M    M  230.00   756721      USGS  ...  NaT
# 59345                  M    M  270.00   757393      USGS  ...  NaT
# 59480                  M    M    0.00   758353      USGS  ...  NaT
# ...                  ...  ...     ...      ...       ...  ...  ...
# 115622                 M    M  330.00  1010187      USGS  ...  NaT
# 115669                 M    M    0.00  1010379      USGS  ...  NaT
# 115670                 M    M    0.00  1010379      USGS  ...  NaT
# 115737                 M    M    0.00  1010667      USGS  ...  NaT
# 115781                 M    M    0.00  1010859      USGS  ...  NaT
#
#        Snow Water Equivalent (in) Change In Snow Water Equivalent (in)  \
# 58954                         NaN                                  NaN
# 59086                         NaN                                  NaN
# 59253                         NaN                                  NaN
# 59345                         NaN                                  NaN
# 59480                         NaN                                  NaN
# ...                           ...                                  ...
# 115622                        NaN                                  NaN
# 115669                        NaN                                  NaN
# 115670                        NaN                                  NaN
# 115737                        NaN                                  NaN
# 115781                        NaN                                  NaN
#
#         Snow Depth (in) Change In Snow Depth (in)  \
# 58954               NaN                       NaN
# 59086               NaN                       NaN
# 59253               NaN                       NaN
# 59345               NaN                       NaN
# 59480               NaN                       NaN
# ...                 ...                       ...
# 115622              NaN                       NaN
# 115669              NaN                       NaN
# 115670              NaN                       NaN
# 115737              NaN                       NaN
# 115781              NaN                       NaN
#
#        Observed Air Temperature (degrees farenheit) filled_snow  \
# 58954                                           NaN           0
# 59086                                           NaN           0
# 59253                                           NaN           0
# 59345                                           NaN           0
# 59480                                           NaN           0
# ...                                             ...         ...
# 115622                                          NaN           7
# 115669                                          NaN           5
# 115670                                          NaN           5
# 115737                                          NaN           5
# 115781                                          NaN           3
#
#                        sensing_time  \
# 58954       2015-08-10 18:33:34 UTC
# 59086       2015-08-20 18:33:19 UTC
# 59253       2015-09-02 18:44:34 UTC
# 59345       2015-09-09 18:33:11 UTC
# 59480       2015-09-19 18:33:12 UTC
# ...                             ...
# 115622  2024-01-08 18:44:55.046 UTC
# 115669  2024-01-10 18:35:02.294 UTC
# 115670  2024-01-10 18:35:02.294 UTC
# 115737  2024-01-13 18:44:57.847 UTC
# 115781  2024-01-15 18:34:56.988 UTC
#
#                                                  base_url  \
# 58954   gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
# 59086   gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
# 59253   gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
# 59345   gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
# 59480   gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
# ...                                                   ...
# 115622  gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
# 115669  gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
# 115670  gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
# 115737  gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
# 115781  gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
#
#                     SENSING_TIME
# 58954  2015-08-10 19:00:00+00:00
# 59086  2015-08-20 19:00:00+00:00
# 59253  2015-09-02 19:00:00+00:00
# 59345  2015-09-09 19:00:00+00:00
# 59480  2015-09-19 19:00:00+00:00
# ...                          ...
# 115622 2024-01-08 19:00:00+00:00
# 115669 2024-01-10 19:00:00+00:00
# 115670 2024-01-10 19:00:00+00:00
# 115737 2024-01-13 19:00:00+00:00
# 115781 2024-01-15 19:00:00+00:00
#
# [866 rows x 27 columns]

# %%
 sentinel_df_11 = sentinel_df[sentinel_df["mgrs_tile"]=="11SMT"]

# %%
sentinel_df_11
# Out:
#         mgrs_tile                                           base_url  \
# 146         11SMT  gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
# 845         11SMT  gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
# 1242        11SMT  gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
# 4992        11SMT  gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
# 5844        11SMT  gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
# ...           ...                                                ...
# 3060558     11SMT  gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
# 3061677     11SMT  gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
# 3067798     11SMT  gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
# 3075924     11SMT  gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
# 3080062     11SMT  gs://gcp-public-data-sentinel-2/tiles/11/S/MT/...
#
#                         sensing_time  cloud_cover
# 146       2017-09-01 18:39:59.64 UTC     2.127500
# 845      2015-12-21 18:45:25.188 UTC    88.000000
# 1242     2015-12-28 18:35:44.592 UTC     1.000000
# 4992     2021-03-01 18:35:04.063 UTC     0.337300
# 5844     2022-07-14 18:35:16.698 UTC    26.654575
# ...                              ...          ...
# 3060558  2023-04-05 18:35:07.188 UTC     0.000000
# 3061677  2022-03-14 18:44:57.622 UTC     0.000000
# 3067798  2020-05-15 18:35:09.265 UTC     0.000000
# 3075924  2016-03-07 18:33:18.891 UTC   100.000000
# 3080062   2017-05-31 18:29:39.39 UTC   100.000000
#
# [1081 rows x 4 columns]

# %%
find = fin_df

# %%
find.to_csv("final_11059300.csv")
